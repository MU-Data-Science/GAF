# %%
import pandas as pd
import numpy as np
data = pd.read_csv('exsamples.csv')

#RDF triplet for Ages
rdf_data = ''
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q11904283>'
    c = '"' + str(data['Age'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#integer>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'
    # print(rdf_data)

#RDF triplet for Assay Type
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q41853466>'
    c = '"' + str(data['Assay Type'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for AvgSpotLen
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q36253>'
    c = '"' + str(data['AvgSpotLen'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#integer>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Bases
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q422960>'
    c = '"' + str(data['Bases'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#integer>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for BioProject
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q114631141>'
    c = '"' + str(data['BioProject'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#integer>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for BioSample
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q111156345>'
    c = '"' + str(data['BioSample'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#integer>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Bytes
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q95959608>'
    c = '"' + str(data['Bytes'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#integer>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Center Name
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q7315155>'
    c = '"' + str(data['Center Name'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for disease
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q12136>'
    c = '"' + str(data['disease'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for disease_stage
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q10960555>'
    c = '"' + str(data['disease_stage'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Experiment
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q101965>'
    c = '"' + str(data['Experiment'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Instrument Model
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q39546>'
    c = '"' + str(data['Instrument'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for GEO Accession (exp)
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q3346344>'
    c = '"' + str(data['GEO_Accession (exp)'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Library Selection
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q11904283>'
    c = '"' + str(data['LibrarySelection'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Library Source
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q11904283>'
    c = '"' + str(data['LibrarySource.1'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Organism Name
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q7239>'
    c = '"' + str(data['Organism'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

# #RDF triplet for Release Date
# for i in range(len(data)):
#     a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
#     b = '<https://www.ncbi.nlm.nih.gov/guide/all/>'
#     c = '"' + str(data['ReleaseDate'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
#     d = '<sg://' + data['Run'].iloc[i] + '>'
#     rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for Sample Name
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q20997795>'
    c = '"' + str(data['Sample Name'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for sex
for i in range(len(data)):
    b = '<https://www.wikidata.org/wiki/Q290>'
    c = '"' + str(data['sex'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for source_name
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q31464082>'
    c = '"' + str(data['source_name'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for SRA Study
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q31464082>'
    c = '"' + str(data['SRA Study'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#RDF triplet for tissue
for i in range(len(data)):
    a = '<https://www.ncbi.nlm.nih.gov/sra/?term=' + data['Run'].iloc[i] + '>'
    b = '<https://www.wikidata.org/wiki/Q40397>'
    c = '"' + str(data['tissue'].iloc[i]) + '"^^<http://www.w3.org/2001/XMLSchema#string>'
    d = '<sg://' + data['Run'].iloc[i] + '>'
    rdf_data += a + ' ' + b + ' ' + c + ' ' + d + ' .\n'

#save into rdf file
with open('metadata_SRR13112995_SRR13112995.nq', 'w') as f:
    f.write(rdf_data)
    
'''
Columns: 'Run', 'Age', 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject',
       'BioSample', 'Bytes', 'Center Name', 'disease', 'disease_stage',
       'Experiment', 'Instrument', 'GEO_Accession (exp)', 'LibrarySelection',
       'LibrarySource', 'Organism', 'ReleaseDate',
       'create_date', 'Sample Name', 'sex', 'source_name', 'SRA Study',
       'tissue'.
WikiData links:
'Age' - <https://www.wikidata.org/wiki/Q11904283>
'Assay Type' - <https://www.wikidata.org/wiki/Q41853466>
'AvgSpotLen' - <https://www.wikidata.org/wiki/Q36253>
'Bases' - <https://www.wikidata.org/wiki/Q422960>
'BioProject' - <https://www.wikidata.org/wiki/Q114631141>
'BioSample' - <https://www.wikidata.org/wiki/Q111156345>
'Bytes' - <https://www.wikidata.org/wiki/Q95959608>
'Center Name' - <https://www.wikidata.org/wiki/Q7315155>
'disease' - <https://www.wikidata.org/wiki/Q12136>
'disease_stage' - <https://www.wikidata.org/wiki/Q10960555>
'Experiment' - <https://www.wikidata.org/wiki/Q101965>
'Instrument' - <https://www.wikidata.org/wiki/Q39546>
'GEO_Accession (exp)' - <https://www.wikidata.org/wiki/Q3346344>
'LibrarySelection' - <https://www.wikidata.org/wiki/Q33290074>
'LibrarySource' - <https://www.wikidata.org/wiki/Q31464082>
'Organism' - <https://www.wikidata.org/wiki/Q7239>
'ReleaseDate' - <https://www.wikidata.org/wiki/Q47150325>
'Sample Name' - <https://www.wikidata.org/wiki/Q20997795>
'sex' - <https://www.wikidata.org/wiki/Q290>
'source_name' - <https://www.wikidata.org/wiki/Q31464082>
'SRA Study' - <https://www.wikidata.org/wiki/Q7452459>
'tissue' - <https://www.wikidata.org/wiki/Q40397> 
'''
# Out:
# "\nColumns: 'Run', 'Age', 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject',\n       'BioSample', 'Bytes', 'Center Name', 'disease', 'disease_stage',\n       'Experiment', 'Instrument', 'GEO_Accession (exp)', 'LibrarySelection',\n       'LibrarySource', 'Organism', 'ReleaseDate',\n       'create_date', 'Sample Name', 'sex', 'source_name', 'SRA Study',\n       'tissue'.\nWikiData links:\n'Age' - <https://www.wikidata.org/wiki/Q11904283>\n'Assay Type' - <https://www.wikidata.org/wiki/Q41853466>\n'AvgSpotLen' - <https://www.wikidata.org/wiki/Q36253>\n'Bases' - <https://www.wikidata.org/wiki/Q422960>\n'BioProject' - <https://www.wikidata.org/wiki/Q114631141>\n'BioSample' - <https://www.wikidata.org/wiki/Q111156345>\n'Bytes' - <https://www.wikidata.org/wiki/Q95959608>\n'Center Name' - <https://www.wikidata.org/wiki/Q7315155>\n'disease' - <https://www.wikidata.org/wiki/Q12136>\n'disease_stage' - <https://www.wikidata.org/wiki/Q10960555>\n'Experiment' - <https://www.wikidata.org/wiki/Q10196
# ...

# %%
# from rdflib import ConjunctiveGraph
# import networkx as nx
# import matplotlib.pyplot as plt

# # Parse the RDF data
# g = ConjunctiveGraph()
# g.parse("metadata_rdf.txt", format="nquads")

# # Create a new directed graph
# G = nx.DiGraph()

# # Add nodes and edges to the graph
# for s, p, o in g:
#     G.add_edge(str(s), str(o), label=str(p))

# # Draw the graph
# pos = nx.spring_layout(G)
# nx.draw(G, pos, with_labels=True, node_size=500)
# edge_labels = nx.get_edge_attributes(G, 'label')
# nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# # Save the graph to a file
# plt.savefig('output.png')

# %%
from rdflib import ConjunctiveGraph, URIRef, Literal
import networkx as nx
import matplotlib.pyplot as plt

# Parse the RDF data
g = ConjunctiveGraph()
g.parse("metadata_rdf.txt", format="nquads")

# Create a new directed graph
G = nx.DiGraph()

# Add nodes and edges to the graph
for quad in g.quads():
    s, p, o, graph = quad
    try:
        if isinstance(o, URIRef):  # Only add edges where the object is a URI
            G.add_edge(str(s), str(o), label=str(graph))
    except ValueError:
        continue  # Skip quads with invalid literals

# Draw the graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=500)
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Save the graph to a file
plt.savefig('output.png')
# Out:
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#integer, Converter=<class 'int'>
# Traceback (most recent call last):
#   File "/Users/ajay/Library/Python/3.9/lib/python/site-packages/rdflib/term.py", line 2119, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
# ValueError: invalid literal for int() with base 10: 'nan'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#integer, Converter=<class 'int'>
# Traceback (most recent call last):
#   File "/Users/ajay/Library/Python/3.9/lib/python/site-packages/rdflib/term.py", line 2119, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
# ValueError: invalid literal for int() with base 10: 'nan'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#integer, Converter=<class 'int'>
# Traceback (most recent call last):
# ...
