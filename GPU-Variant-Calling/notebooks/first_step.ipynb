# %% [markdown]
# # First fabric experiment
#
# Prerequisites: Create an account with the fabric testbed. Please follow all the instructions given in <code> configure_environment.ipynb</code> which can be easily located via <code> start_here.ipynb</code> inside the <code> fabric_example</code> folder. <code> configure_environment.ipynb</code> contains instructions about setting up the fabric environment.

# %% [markdown]
# ### Import the fabric library
#
# The fabric library contains functions that can be used to access all the underlying API.

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib= fablib_manager()

# This function is not necessary but can be used to see the environment settings
fablib.show_config()
# Out:
# <style type="text/css">
# #T_0df6c tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0df6c tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0df6c caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_0df6c_row0_col0, #T_0df6c_row0_col1, #T_0df6c_row1_col0, #T_0df6c_row1_col1, #T_0df6c_row2_col0, #T_0df6c_row2_col1, #T_0df6c_row3_col0, #T_0df6c_row3_col1, #T_0df6c_row4_col0, #T_0df6c_row4_col1, #T_0df6c_row5_col0, #T_0df6c_row5_col1, #T_0df6c_row6_col0, #T_0df6c_row6_col1, #T_0df6c_row7_col0, #T_0df6c_row7_col1, #T_0df6c_row8_col0, #T_0df6c_row8_col1, #T_0df6c_row9_col0, #T_0df6c_row9_col1, #T_0df6c_row10_col0, #T_0df6c_row10_col1, #T_0df6c_row11_col0, #T_0df6c_row11_col1, #T_0df6c_row12_col0, #T_0df6c_row12_col1, #T_0df6c_row13_col0, #T_0df6c_row13_col1, #T_0df6c_row14_col0, #T_0df6c_row14_col1, #T_0df6c_row15_col0, #T_0df6c_row15_col1, #T_0df6c_row16_col0, #T_0df6c_row16_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_0df6c">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0df6c_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_0df6c_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_0df6c_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_0df6c_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_0df6c_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_0df6c_row4_col1" class="data row4 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row5_col0" class="data row5 col0" >Bastion Host</td>
#       <td id="T_0df6c_row5_col1" class="data row5 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row6_col0" class="data row6 col0" >Bastion Username</td>
#       <td id="T_0df6c_row6_col1" class="data row6 col1" >ajaykumar_0000102567</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row7_col0" class="data row7 col0" >Bastion Private Key File</td>
#       <td id="T_0df6c_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_0df6c_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_0df6c_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row10_col0" class="data row10 col0" >Sites to avoid</td>
#       <td id="T_0df6c_row10_col1" class="data row10 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row11_col0" class="data row11 col0" >SSH Command Line</td>
#       <td id="T_0df6c_row11_col1" class="data row11 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_0df6c_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row13_col0" class="data row13 col0" >Log File</td>
#       <td id="T_0df6c_row13_col1" class="data row13 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row14_col0" class="data row14 col0" >Bastion SSH Config File</td>
#       <td id="T_0df6c_row14_col1" class="data row14 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row15_col0" class="data row15 col0" >Version</td>
#       <td id="T_0df6c_row15_col1" class="data row15 col1" >1.6.2</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row16_col0" class="data row16 col0" >Data directory</td>
#       <td id="T_0df6c_row16_col1" class="data row16 col1" >/tmp/fablib</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0df6c tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0df6c tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0df6c caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_0df6c_row0_col0, #T_0df6c_row0_col1, #T_0df6c_row1_col0, #T_0df6c_row1_col1, #T_0df6c_row2_col0, #T_0df6c_row2_col1, #T_0df6c_row3_col0, #T_0df6c_row3_col1, #T_0df6c_row4_col0, #T_0df6c_row4_col1, #T_0df6c_row5_col0, #T_0df6c_row5_col1, #T_0df6c_row6_col0, #T_0df6c_row6_col1, #T_0df6c_row7_col0, #T_0df6c_row7_col1, #T_0df6c_row8_col0, #T_0df6c_row8_col1, #T_0df6c_row9_col0, #T_0df6c_row9_col1, #T_0df6c_row10_col0, #T_0df6c_row10_col1, #T_0df6c_row11_col0, #T_0df6c_row11_col1, #T_0df6c_row12_col0, #T_0df6c_row12_col1, #T_0df6c_row13_col0, #T_0df6c_row13_col1, #T_0df6c_row14_col0, #T_0df6c_row14_col1, #T_0df6c_row15_col0, #T_0df6c_row15_col1, #T_0df6c_row16_col0, #T_0df6c_row16_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_0df6c">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0df6c_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_0df6c_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_0df6c_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_0df6c_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_0df6c_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_0df6c_row4_col1" class="data row4 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row5_col0" class="data row5 col0" >Bastion Host</td>
#       <td id="T_0df6c_row5_col1" class="data row5 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row6_col0" class="data row6 col0" >Bastion Username</td>
#       <td id="T_0df6c_row6_col1" class="data row6 col1" >ajaykumar_0000102567</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row7_col0" class="data row7 col0" >Bastion Private Key File</td>
#       <td id="T_0df6c_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_0df6c_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_0df6c_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row10_col0" class="data row10 col0" >Sites to avoid</td>
#       <td id="T_0df6c_row10_col1" class="data row10 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row11_col0" class="data row11 col0" >SSH Command Line</td>
#       <td id="T_0df6c_row11_col1" class="data row11 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_0df6c_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row13_col0" class="data row13 col0" >Log File</td>
#       <td id="T_0df6c_row13_col1" class="data row13 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row14_col0" class="data row14 col0" >Bastion SSH Config File</td>
#       <td id="T_0df6c_row14_col1" class="data row14 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row15_col0" class="data row15 col0" >Version</td>
#       <td id="T_0df6c_row15_col1" class="data row15 col1" >1.6.2</td>
#     </tr>
#     <tr>
#       <td id="T_0df6c_row16_col0" class="data row16 col0" >Data directory</td>
#       <td id="T_0df6c_row16_col1" class="data row16 col1" >/tmp/fablib</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Finding Resources:
#
# To find available resources in the fabric testbed.

# %%
try:
    print(f"{fablib.list_sites()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_b4839 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b4839 th {
#   text-align: left;
# }
# #T_b4839 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b4839 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b4839 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b4839_row0_col0, #T_b4839_row0_col1, #T_b4839_row0_col2, #T_b4839_row0_col3, #T_b4839_row0_col4, #T_b4839_row0_col5, #T_b4839_row0_col6, #T_b4839_row0_col7, #T_b4839_row0_col8, #T_b4839_row0_col9, #T_b4839_row0_col10, #T_b4839_row0_col11, #T_b4839_row0_col12, #T_b4839_row0_col13, #T_b4839_row0_col14, #T_b4839_row0_col15, #T_b4839_row0_col16, #T_b4839_row0_col17, #T_b4839_row0_col18, #T_b4839_row0_col19, #T_b4839_row0_col20, #T_b4839_row0_col21, #T_b4839_row0_col22, #T_b4839_row0_col23, #T_b4839_row0_col24, #T_b4839_row0_col25, #T_b4839_row0_col26, #T_b4839_row0_col27, #T_b4839_row0_col28, #T_b4839_row0_col29, #T_b4839_row0_col30, #T_b4839_row0_col31, #T_b4839_row0_col32, #T_b4839_row0_col33, #T_b4839_row0_col34, #T_b4839_row0_col35, #T_b4839_row0_col36, #T_b4839_row0_col37, #T_b4839_row0_col38, #T_b4839_row0_col39, #T_b4839_row0_col40, #T_b4839_row0_col41, #T_b4839_row0_col42, #T_b4839_row1_col0, #T_b4839_row1_col1, #T_b4839_row1_col2, #T_b4839_row1_col3, #T_b4839_row1_col4, #T_b4839_row1_col5, #T_b4839_row1_col6, #T_b4839_row1_col7, #T_b4839_row1_col8, #T_b4839_row1_col9, #T_b4839_row1_col10, #T_b4839_row1_col11, #T_b4839_row1_col12, #T_b4839_row1_col13, #T_b4839_row1_col14, #T_b4839_row1_col15, #T_b4839_row1_col16, #T_b4839_row1_col17, #T_b4839_row1_col18, #T_b4839_row1_col19, #T_b4839_row1_col20, #T_b4839_row1_col21, #T_b4839_row1_col22, #T_b4839_row1_col23, #T_b4839_row1_col24, #T_b4839_row1_col25, #T_b4839_row1_col26, #T_b4839_row1_col27, #T_b4839_row1_col28, #T_b4839_row1_col29, #T_b4839_row1_col30, #T_b4839_row1_col31, #T_b4839_row1_col32, #T_b4839_row1_col33, #T_b4839_row1_col34, #T_b4839_row1_col35, #T_b4839_row1_col36, #T_b4839_row1_col37, #T_b4839_row1_col38, #T_b4839_row1_col39, #T_b4839_row1_col40, #T_b4839_row1_col41, #T_b4839_row1_col42, #T_b4839_row2_col0, #T_b4839_row2_col1, #T_b4839_row2_col2, #T_b4839_row2_col3, #T_b4839_row2_col4, #T_b4839_row2_col5, #T_b4839_row2_col6, #T_b4839_row2_col7, #T_b4839_row2_col8, #T_b4839_row2_col9, #T_b4839_row2_col10, #T_b4839_row2_col11, #T_b4839_row2_col12, #T_b4839_row2_col13, #T_b4839_row2_col14, #T_b4839_row2_col15, #T_b4839_row2_col16, #T_b4839_row2_col17, #T_b4839_row2_col18, #T_b4839_row2_col19, #T_b4839_row2_col20, #T_b4839_row2_col21, #T_b4839_row2_col22, #T_b4839_row2_col23, #T_b4839_row2_col24, #T_b4839_row2_col25, #T_b4839_row2_col26, #T_b4839_row2_col27, #T_b4839_row2_col28, #T_b4839_row2_col29, #T_b4839_row2_col30, #T_b4839_row2_col31, #T_b4839_row2_col32, #T_b4839_row2_col33, #T_b4839_row2_col34, #T_b4839_row2_col35, #T_b4839_row2_col36, #T_b4839_row2_col37, #T_b4839_row2_col38, #T_b4839_row2_col39, #T_b4839_row2_col40, #T_b4839_row2_col41, #T_b4839_row2_col42, #T_b4839_row3_col0, #T_b4839_row3_col1, #T_b4839_row3_col2, #T_b4839_row3_col3, #T_b4839_row3_col4, #T_b4839_row3_col5, #T_b4839_row3_col6, #T_b4839_row3_col7, #T_b4839_row3_col8, #T_b4839_row3_col9, #T_b4839_row3_col10, #T_b4839_row3_col11, #T_b4839_row3_col12, #T_b4839_row3_col13, #T_b4839_row3_col14, #T_b4839_row3_col15, #T_b4839_row3_col16, #T_b4839_row3_col17, #T_b4839_row3_col18, #T_b4839_row3_col19, #T_b4839_row3_col20, #T_b4839_row3_col21, #T_b4839_row3_col22, #T_b4839_row3_col23, #T_b4839_row3_col24, #T_b4839_row3_col25, #T_b4839_row3_col26, #T_b4839_row3_col27, #T_b4839_row3_col28, #T_b4839_row3_col29, #T_b4839_row3_col30, #T_b4839_row3_col31, #T_b4839_row3_col32, #T_b4839_row3_col33, #T_b4839_row3_col34, #T_b4839_row3_col35, #T_b4839_row3_col36, #T_b4839_row3_col37, #T_b4839_row3_col38, #T_b4839_row3_col39, #T_b4839_row3_col40, #T_b4839_row3_col41, #T_b4839_row3_col42, #T_b4839_row4_col0, #T_b4839_row4_col1, #T_b4839_row4_col2, #T_b4839_row4_col3, #T_b4839_row4_col4, #T_b4839_row4_col5, #T_b4839_row4_col6, #T_b4839_row4_col7, #T_b4839_row4_col8, #T_b4839_row4_col9, #T_b4839_row4_col10, #T_b4839_row4_col11, #T_b4839_row4_col12, #T_b4839_row4_col13, #T_b4839_row4_col14, #T_b4839_row4_col15, #T_b4839_row4_col16, #T_b4839_row4_col17, #T_b4839_row4_col18, #T_b4839_row4_col19, #T_b4839_row4_col2 ...
# <pandas.io.formats.style.Styler object at 0x7f8f0fa27a90>

# %% [markdown]
# ### Creating a slice
#
# A slice is a collection of compute resources stitched together to form some topology. In this experiment we will be creating a single node, with basic compute resources added to it. We can choose the resources from the table shown above (output of Finding Resources section). Experimenters usually get equal or more than the requested amount of compute resources.

# %%
# Naming the resources
slice_name="First_slice"
node1_name="Node1"

# %%
try:
    slice=fablib.new_slice(name=slice_name)
    
    node1=slice.add_node(name=node1_name,
                         site='STAR', # name of the site, please see above table for other options.
                         host='star-w2.fabric-testbed.net', # address of the STAR site worker
                         cores=4, # number of cores
                         ram=8, # amount of RAM
                         disk=10, # Disk space
                         image='default_ubuntu_20') # operation system type
    slice.submit()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Retry: 9, Time: 226 sec
# <style type="text/css">
# #T_139de tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_139de tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_139de caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_139de_row0_col0, #T_139de_row0_col1, #T_139de_row1_col0, #T_139de_row1_col1, #T_139de_row2_col0, #T_139de_row2_col1, #T_139de_row3_col0, #T_139de_row3_col1, #T_139de_row4_col0, #T_139de_row4_col1, #T_139de_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_139de_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_139de">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_139de_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_139de_row0_col1" class="data row0 col1" >078c2e59-8e09-443f-b03f-5cd7f3a67923</td>
#     </tr>
#     <tr>
#       <td id="T_139de_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_139de_row1_col1" class="data row1 col1" >First_slice</td>
#     </tr>
#     <tr>
#       <td id="T_139de_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_139de_row2_col1" class="data row2 col1" >2024-04-25 20:08:31 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_139de_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_139de_row3_col1" class="data row3 col1" >2024-04-24 20:08:32 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_139de_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_139de_row4_col1" class="data row4 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_139de_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_139de_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e8ecb caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e8ecb th {
#   text-align: left;
# }
# #T_e8ecb tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e8ecb tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e8ecb .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e8ecb_row0_col0, #T_e8ecb_row0_col1, #T_e8ecb_row0_col2, #T_e8ecb_row0_col3, #T_e8ecb_row0_col4, #T_e8ecb_row0_col5, #T_e8ecb_row0_col6, #T_e8ecb_row0_col7, #T_e8ecb_row0_col8, #T_e8ecb_row0_col9, #T_e8ecb_row0_col10, #T_e8ecb_row0_col13, #T_e8ecb_row0_col14, #T_e8ecb_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_e8ecb_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_e8ecb_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_e8ecb">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_e8ecb_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e8ecb_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_e8ecb_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_e8ecb_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_e8ecb_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_e8ecb_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_e8ecb_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_e8ecb_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_e8ecb_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_e8ecb_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_e8ecb_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_e8ecb_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_e8ecb_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_e8ecb_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_e8ecb_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_e8ecb_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e8ecb_row0_col0" class="data row0 col0" >9c800f9d-504a-44b8-b81e-3469bd99934f</td>
#       <td id="T_e8ecb_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_e8ecb_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_e8ecb_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_e8ecb_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_e8ecb_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_e8ecb_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_e8ecb_row0_col7" class="data row0 col7" >star-w2.fabric-testbed.net</td>
#       <td id="T_e8ecb_row0_col8" class="data row0 col8" >STAR</td>
#       <td id="T_e8ecb_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_e8ecb_row0_col10" class="data row0 col10" >2001:400:a100:3030:f816:3eff:feb2:3b3a</td>
#       <td id="T_e8ecb_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_e8ecb_row0_col12" class="data row0 col12" ></td>
#       <td id="T_e8ecb_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3030:f816:3eff:feb2:3b3a</td>
#       <td id="T_e8ecb_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_e8ecb_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### List Slice Attributes

# %%
try:
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------  ------------------------------------
# Slice Name   First_slice
# Slice ID     078c2e59-8e09-443f-b03f-5cd7f3a67923
# Slice State  StableOK
# Lease End    2024-04-25 20:08:31 +0000
# -----------  ------------------------------------

# %% [markdown]
# ### List Node Attributes

# %%
try:
    for node in slice.get_nodes():
        print(f"{node}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# ID                 9c800f9d-504a-44b8-b81e-3469bd99934f
# Name               Node1
# Cores              4
# RAM                8
# Disk               10
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               star-w2.fabric-testbed.net
# Site               STAR
# Management IP      2001:400:a100:3030:f816:3eff:feb2:3b3a
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3030:f816:3eff:feb2:3b3a
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Running a simple experiment
#
# A simple experiment to add two numbers.

# %%
try:
    node=slice.get_node(name=node1_name)
    stdout, stderr=node.execute("echo '1 + 1' | bc")
    
    print(stdout)
    print(stderr)
    
except Exception as e:
    print(f"Excetion: {e}")
# Out:
# 2
# 2

# %% [markdown]
# ### Delete the slice
#
# Delete the slice after the experiment is over.

# %%
try:
    slice=fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
