# %% [markdown]
# # Creating a cluster/slice

# %% [markdown]
# ## Please read carefully all the instructions. Specially the comments given in each cell. These comments are pertinent to run a cluster successfully.
#
# If the fabric environment is not set please read through the topic <code>FABRIC Environment Setup</code> in <code>start_here.ipynb</code> notebook given under <code>jupyter-example</code> folder in fabric's JupyterHub.
#
# <b> At first read the comments in the cell and then only run the cell. </b>

# %% [markdown]
# ## STEP-1

# %%
# Run this cell.

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
                     
    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_5f8d0 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5f8d0 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5f8d0 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5f8d0_row0_col0, #T_5f8d0_row0_col1, #T_5f8d0_row1_col0, #T_5f8d0_row1_col1, #T_5f8d0_row2_col0, #T_5f8d0_row2_col1, #T_5f8d0_row3_col0, #T_5f8d0_row3_col1, #T_5f8d0_row4_col0, #T_5f8d0_row4_col1, #T_5f8d0_row5_col0, #T_5f8d0_row5_col1, #T_5f8d0_row6_col0, #T_5f8d0_row6_col1, #T_5f8d0_row7_col0, #T_5f8d0_row7_col1, #T_5f8d0_row8_col0, #T_5f8d0_row8_col1, #T_5f8d0_row9_col0, #T_5f8d0_row9_col1, #T_5f8d0_row10_col0, #T_5f8d0_row10_col1, #T_5f8d0_row11_col0, #T_5f8d0_row11_col1, #T_5f8d0_row12_col0, #T_5f8d0_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5f8d0">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f8d0_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_5f8d0_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_5f8d0_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_5f8d0_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_5f8d0_row3_col1" class="data row3 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_5f8d0_row4_col1" class="data row4 col1" >mjdbz4_0000018266</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_5f8d0_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_5f8d0_row6_col1" class="data row6 col1" >bastion-1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_5f8d0_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_5f8d0_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_5f8d0_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_5f8d0_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_5f8d0_row11_col1" class="data row11 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_5f8d0_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_5f8d0_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Run this cell
# To find all the available resources at this time
try:
    print(f"{fablib.list_sites()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_e075d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e075d th {
#   text-align: left;
# }
# #T_e075d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e075d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e075d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e075d_row0_col0, #T_e075d_row0_col1, #T_e075d_row0_col2, #T_e075d_row0_col3, #T_e075d_row0_col4, #T_e075d_row0_col5, #T_e075d_row0_col6, #T_e075d_row0_col7, #T_e075d_row0_col8, #T_e075d_row0_col9, #T_e075d_row0_col10, #T_e075d_row0_col11, #T_e075d_row0_col12, #T_e075d_row0_col13, #T_e075d_row0_col14, #T_e075d_row0_col15, #T_e075d_row0_col16, #T_e075d_row0_col17, #T_e075d_row0_col18, #T_e075d_row0_col19, #T_e075d_row0_col20, #T_e075d_row0_col21, #T_e075d_row0_col22, #T_e075d_row0_col23, #T_e075d_row0_col24, #T_e075d_row0_col25, #T_e075d_row0_col26, #T_e075d_row0_col27, #T_e075d_row0_col28, #T_e075d_row0_col29, #T_e075d_row0_col30, #T_e075d_row0_col31, #T_e075d_row1_col0, #T_e075d_row1_col1, #T_e075d_row1_col2, #T_e075d_row1_col3, #T_e075d_row1_col4, #T_e075d_row1_col5, #T_e075d_row1_col6, #T_e075d_row1_col7, #T_e075d_row1_col8, #T_e075d_row1_col9, #T_e075d_row1_col10, #T_e075d_row1_col11, #T_e075d_row1_col12, #T_e075d_row1_col13, #T_e075d_row1_col14, #T_e075d_row1_col15, #T_e075d_row1_col16, #T_e075d_row1_col17, #T_e075d_row1_col18, #T_e075d_row1_col19, #T_e075d_row1_col20, #T_e075d_row1_col21, #T_e075d_row1_col22, #T_e075d_row1_col23, #T_e075d_row1_col24, #T_e075d_row1_col25, #T_e075d_row1_col26, #T_e075d_row1_col27, #T_e075d_row1_col28, #T_e075d_row1_col29, #T_e075d_row1_col30, #T_e075d_row1_col31, #T_e075d_row2_col0, #T_e075d_row2_col1, #T_e075d_row2_col2, #T_e075d_row2_col3, #T_e075d_row2_col4, #T_e075d_row2_col5, #T_e075d_row2_col6, #T_e075d_row2_col7, #T_e075d_row2_col8, #T_e075d_row2_col9, #T_e075d_row2_col10, #T_e075d_row2_col11, #T_e075d_row2_col12, #T_e075d_row2_col13, #T_e075d_row2_col14, #T_e075d_row2_col15, #T_e075d_row2_col16, #T_e075d_row2_col17, #T_e075d_row2_col18, #T_e075d_row2_col19, #T_e075d_row2_col20, #T_e075d_row2_col21, #T_e075d_row2_col22, #T_e075d_row2_col23, #T_e075d_row2_col24, #T_e075d_row2_col25, #T_e075d_row2_col26, #T_e075d_row2_col27, #T_e075d_row2_col28, #T_e075d_row2_col29, #T_e075d_row2_col30, #T_e075d_row2_col31, #T_e075d_row3_col0, #T_e075d_row3_col1, #T_e075d_row3_col2, #T_e075d_row3_col3, #T_e075d_row3_col4, #T_e075d_row3_col5, #T_e075d_row3_col6, #T_e075d_row3_col7, #T_e075d_row3_col8, #T_e075d_row3_col9, #T_e075d_row3_col10, #T_e075d_row3_col11, #T_e075d_row3_col12, #T_e075d_row3_col13, #T_e075d_row3_col14, #T_e075d_row3_col15, #T_e075d_row3_col16, #T_e075d_row3_col17, #T_e075d_row3_col18, #T_e075d_row3_col19, #T_e075d_row3_col20, #T_e075d_row3_col21, #T_e075d_row3_col22, #T_e075d_row3_col23, #T_e075d_row3_col24, #T_e075d_row3_col25, #T_e075d_row3_col26, #T_e075d_row3_col27, #T_e075d_row3_col28, #T_e075d_row3_col29, #T_e075d_row3_col30, #T_e075d_row3_col31, #T_e075d_row4_col0, #T_e075d_row4_col1, #T_e075d_row4_col2, #T_e075d_row4_col3, #T_e075d_row4_col4, #T_e075d_row4_col5, #T_e075d_row4_col6, #T_e075d_row4_col7, #T_e075d_row4_col8, #T_e075d_row4_col9, #T_e075d_row4_col10, #T_e075d_row4_col11, #T_e075d_row4_col12, #T_e075d_row4_col13, #T_e075d_row4_col14, #T_e075d_row4_col15, #T_e075d_row4_col16, #T_e075d_row4_col17, #T_e075d_row4_col18, #T_e075d_row4_col19, #T_e075d_row4_col20, #T_e075d_row4_col21, #T_e075d_row4_col22, #T_e075d_row4_col23, #T_e075d_row4_col24, #T_e075d_row4_col25, #T_e075d_row4_col26, #T_e075d_row4_col27, #T_e075d_row4_col28, #T_e075d_row4_col29, #T_e075d_row4_col30, #T_e075d_row4_col31, #T_e075d_row5_col0, #T_e075d_row5_col1, #T_e075d_row5_col2, #T_e075d_row5_col3, #T_e075d_row5_col4, #T_e075d_row5_col5, #T_e075d_row5_col6, #T_e075d_row5_col7, #T_e075d_row5_col8, #T_e075d_row5_col9, #T_e075d_row5_col10, #T_e075d_row5_col11, #T_e075d_row5_col12, #T_e075d_row5_col13, #T_e075d_row5_col14, #T_e075d_row5_col15, #T_e075d_row5_col16, #T_e075d_row5_col17, #T_e075d_row5_col18, #T_e075d_row5_col19, #T_e075d_row5_col20, #T_e075d_row5_col21, #T_e075d_row5_col22, #T_e075d_row5_col23, #T_e075d_row5_col24, #T_e075d_row5_col25, #T_e075d_row5_col26, #T_e075d_row5_col27, #T_e075d_row5_col28, #T_e075d_row5_col29, #T_e075d_row5_col30, #T_e075d_row5_col31, #T_e075d_row6_col0, #T_e075d ...
# <pandas.io.formats.style.Styler object at 0x7fbe400e6c10>

# %% [markdown]
# ## Step-2

# %% [markdown]
# # Creating a cluster
#
# There are many ways you can create a cluster. Some of which are shown below, follow ONLY one strategy. Either <b>Step-2(a) or Step-2(b)</b>

# %% [markdown]
# ### Step-2(a): Creating a cluster by allocating the resources explicitly.

# %%
# Run this cell
# Initialize the variables appropriately. 


# Number of nodes in the cluster.
num_nodes=8
# Give a cluster name
slice_name='cluster_gatk'
# Make it True if you want to include persistence storage to a single node. KEEP IT FALSE FOR THE TIME BEING.
storage=True
# Site name, pick one site from the above list of resources.
site='GPN'
# Number of cores
cores=20
# Capacity of RAM in Gbs
ram=128
# capacity of disk in Gbs
disk=1000
# Operation system, Linux distribution e.g. default_ubuntu_18, default_ubuntu_20, etc.
image='default_ubuntu_18'

# %%
# Run this cell

# The general syntax for host name: {site_name}-w{1-9}.fabric-testbed.net 
if site.isupper():
    host_lower=site.lower()
host_lower="{0}-w3.fabric-testbed.net".format(host_lower) 

node_names=[]
nic_names=[]
iface_names=[]
network_name='cluster_network'
storage_name = 'gaf-storage'
 

for i in range(1,num_nodes+1):
    node_names.append("Node{0}".format(i))
    nic_names.append("Nic{0}".format(i))
    iface_names.append("iface{0}".format(i))

print(node_names)
print(nic_names)
print(iface_names)
# Out:
# ['Node1', 'Node2', 'Node3', 'Node4', 'Node5', 'Node6', 'Node7', 'Node8']
# ['Nic1', 'Nic2', 'Nic3', 'Nic4', 'Nic5', 'Nic6', 'Nic7', 'Nic8']
# ['iface1', 'iface2', 'iface3', 'iface4', 'iface5', 'iface6', 'iface7', 'iface8']

# %%
# Only run when persistence storage needed to be attached.
if storage == True:
    import traceback
    from plugins import Plugins
    try:
        Plugins.load()
    except Exception as e:
        traceback.print_exc()

# %%
# Run this cell
# Read the comments carefully given below and make changes as necessary. 

try:
    slice=fablib.new_slice(name=slice_name)
    
    for i in range(num_nodes):
        if storage == True and i == 0:
            node=slice.add_node(name=node_names[i],
                                site=site,
                                cores=cores,
                                ram=ram,
                                disk=disk,
                                image=image)
            node.add_storage(name=storage_name)
            iface_names[i]=node.add_component(model='NIC_Basic', name=node_names[i]).get_interfaces()[0]
        
        else:
            node=slice.add_node(name=node_names[i],
                                site=site,
                                cores=cores,
                                ram=ram,
                                disk=disk,
                                image=image)
            iface_names[i]=node.add_component(model='NIC_Basic',name=node_names[i]).get_interfaces()[0]
            
except Exception as e:
    print(f'Exception: {e}')

# %%
# Run this cell
try:
    net_cluster=slice.add_l2network(name=network_name, interfaces=iface_names[:])
except Exception as e:
    print(f"Exception: {e}")

# %%
# Run this cell
# If this cell get executed successfully then IP address of the nodes will be displayed which can be used to ssh into the respective nodes.
# If there is an error while creating the slice/cluster, repeat from the third code cell block.

try:
    slice.submit()
except Exception as e:
    print(f'Exception: {e}')
# Out:
# Retry: 6, Time: 246 sec
# <style type="text/css">
# #T_e91c6 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e91c6 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e91c6 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_e91c6_row0_col0, #T_e91c6_row0_col1, #T_e91c6_row1_col0, #T_e91c6_row1_col1, #T_e91c6_row2_col0, #T_e91c6_row2_col1, #T_e91c6_row3_col0, #T_e91c6_row3_col1, #T_e91c6_row4_col0, #T_e91c6_row4_col1, #T_e91c6_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_e91c6_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# </style>
# <table id="T_e91c6">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e91c6_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_e91c6_row0_col1" class="data row0 col1" >8fd889d3-f6d8-42dc-b23f-a0f12485d8bb</td>
#     </tr>
#     <tr>
#       <td id="T_e91c6_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_e91c6_row1_col1" class="data row1 col1" >cluster_gatk</td>
#     </tr>
#     <tr>
#       <td id="T_e91c6_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_e91c6_row2_col1" class="data row2 col1" >2023-01-31 21:44:04 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_e91c6_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_e91c6_row3_col1" class="data row3 col1" >2023-01-30 21:44:05 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_e91c6_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_e91c6_row4_col1" class="data row4 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_e91c6_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_e91c6_row5_col1" class="data row5 col1" >Configuring</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_697fa caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_697fa th {
#   text-align: left;
# }
# #T_697fa tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_697fa tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_697fa .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_697fa_row0_col0, #T_697fa_row0_col1, #T_697fa_row0_col2, #T_697fa_row0_col3, #T_697fa_row0_col4, #T_697fa_row0_col5, #T_697fa_row0_col6, #T_697fa_row0_col7, #T_697fa_row0_col8, #T_697fa_row0_col9, #T_697fa_row0_col10, #T_697fa_row0_col13, #T_697fa_row0_col14, #T_697fa_row0_col15, #T_697fa_row1_col0, #T_697fa_row1_col1, #T_697fa_row1_col2, #T_697fa_row1_col3, #T_697fa_row1_col4, #T_697fa_row1_col5, #T_697fa_row1_col6, #T_697fa_row1_col7, #T_697fa_row1_col8, #T_697fa_row1_col9, #T_697fa_row1_col10, #T_697fa_row1_col13, #T_697fa_row1_col14, #T_697fa_row1_col15, #T_697fa_row2_col0, #T_697fa_row2_col1, #T_697fa_row2_col2, #T_697fa_row2_col3, #T_697fa_row2_col4, #T_697fa_row2_col5, #T_697fa_row2_col6, #T_697fa_row2_col7, #T_697fa_row2_col8, #T_697fa_row2_col9, #T_697fa_row2_col10, #T_697fa_row2_col13, #T_697fa_row2_col14, #T_697fa_row2_col15, #T_697fa_row3_col0, #T_697fa_row3_col1, #T_697fa_row3_col2, #T_697fa_row3_col3, #T_697fa_row3_col4, #T_697fa_row3_col5, #T_697fa_row3_col6, #T_697fa_row3_col7, #T_697fa_row3_col8, #T_697fa_row3_col9, #T_697fa_row3_col10, #T_697fa_row3_col13, #T_697fa_row3_col14, #T_697fa_row3_col15, #T_697fa_row4_col0, #T_697fa_row4_col1, #T_697fa_row4_col2, #T_697fa_row4_col3, #T_697fa_row4_col4, #T_697fa_row4_col5, #T_697fa_row4_col6, #T_697fa_row4_col7, #T_697fa_row4_col8, #T_697fa_row4_col9, #T_697fa_row4_col10, #T_697fa_row4_col13, #T_697fa_row4_col14, #T_697fa_row4_col15, #T_697fa_row5_col0, #T_697fa_row5_col1, #T_697fa_row5_col2, #T_697fa_row5_col3, #T_697fa_row5_col4, #T_697fa_row5_col5, #T_697fa_row5_col6, #T_697fa_row5_col7, #T_697fa_row5_col8, #T_697fa_row5_col9, #T_697fa_row5_col10, #T_697fa_row5_col13, #T_697fa_row5_col14, #T_697fa_row5_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_697fa_row0_col11, #T_697fa_row5_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# #T_697fa_row0_col12, #T_697fa_row1_col11, #T_697fa_row2_col12, #T_697fa_row3_col11, #T_697fa_row4_col11, #T_697fa_row5_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_697fa_row1_col12, #T_697fa_row3_col12, #T_697fa_row4_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffb7b9;
# }
# #T_697fa_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_697fa">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_697fa_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_697fa_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_697fa_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_697fa_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_697fa_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_697fa_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_697fa_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_697fa_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_697fa_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_697fa_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_697fa_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_697fa_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_697fa_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_697fa_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_697fa_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_697fa_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_697fa_row0_col0" class="data row0 col0" >70e402b4-0ce5-4213-9df6-5ff3597c8abf</td>
#       <td id="T_697fa_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_697fa_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_697fa_row0_col3" class="data row0 col3" >128</td>
#       <td id="T_697fa_row0_col4" class="data row0 col4" >2000</td>
#       <td id="T_697fa_row0_col5" class="data row0 col5" >default_ubuntu_18</td>
#       <td id="T_697fa_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_697fa_row0_col7" class="data row0 col7" >ucsd-w2.fabric-testbed.net</td>
#       <td id="T_697fa_row0_col8" class="data row0 col8" >UCSD</td>
#       <td id="T_697fa_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_697fa_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_697fa_row0_col11" class="data row0 col11" >Ticketed</td>
#       <td id="T_697fa_row0_col12" class="data row0 col12" ></td>
#       <td id="T_697fa_row0_col13" class="data row0 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_697fa_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_697fa_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_697fa_row1_col0" class="data row1 col0" >04139d1d-1da4-4aea-aa4b-5733b1afeb41</td>
#       <td id="T_697fa_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_697fa_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_697fa_row1_col3" class="data row1 col3" >128</td>
#       <td id="T_697fa_row1_col4" class="data row1 col4" >2000</td>
#       <td id="T_697fa_row1_col5" class="data row1 col5" >default_ubuntu_18</td>
#       <td id="T_697fa_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_697fa_row1_col7" class="data row1 col7" >ucsd-w3.fabric-testbed.net</td>
#       <td id="T_697fa_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_697fa_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_697fa_row1_col10" class="data row1 col10" >None</td>
#       <td id="T_697fa_row1_col11" class="data row1 col11" >Failed</td>
#       <td id="T_697fa_row1_col12" class="data row1 col12" >failed lease update- all units failed priming: Exception during create for unit: 04139d1d-1da4-4aea-aa4b-5733b1afeb41 Playbook has failed tasks: Error in creating the server (no further information available)#all units failed priming: Exception during create for unit: 04139d1d-1da4-4aea-aa4b-5733b1afeb41 Playbook has failed tasks: Error in creating the server (no further information available)#</td>
#       <td id="T_697fa_row1_col13" class="data row1 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_697fa_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_697fa_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_697fa_row2_col0" class="data row2 col0" >4b1a874a-7670-4b27-b4b9-2c1ce01ef98c</td>
#       <td id="T_697fa_row2_col1" class="data row2 col1" >Node3</td>
#       <td id="T_697fa_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_697fa_row2_col3" class="data row2 col3" >128</td>
#       <td id="T_697fa_row2_col4" class="data row2 col4" >2000</td>
#       <td id="T_697fa_row2_col5" class="data row2 col5" >default_ubuntu_18</td>
#       <td id="T_697fa_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_697fa_row2_col7" class="data row2 col7" >ucsd-w3.fabric-testbed.net</td>
#       <td id="T_697fa_row2_col8" class="data row2 col8" >UCSD</td>
#       <td id="T_697fa_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td i
# <style type="text/css">
# #T_94a5e caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_94a5e th {
#   text-align: left;
# }
# #T_94a5e tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_94a5e tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_94a5e .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_94a5e_row0_col0, #T_94a5e_row0_col1, #T_94a5e_row0_col2, #T_94a5e_row0_col3, #T_94a5e_row0_col4, #T_94a5e_row0_col5, #T_94a5e_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_94a5e_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# #T_94a5e_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_94a5e">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_94a5e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_94a5e_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_94a5e_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_94a5e_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_94a5e_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_94a5e_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_94a5e_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_94a5e_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_94a5e_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94a5e_row0_col0" class="data row0 col0" >fe2a0f90-4c33-4c76-aeb4-f20ec33bddb8</td>
#       <td id="T_94a5e_row0_col1" class="data row0 col1" >cluster_network</td>
#       <td id="T_94a5e_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_94a5e_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_94a5e_row0_col4" class="data row0 col4" >UCSD</td>
#       <td id="T_94a5e_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_94a5e_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_94a5e_row0_col7" class="data row0 col7" >Ticketed</td>
#       <td id="T_94a5e_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step-2(b): Creating a cluster from an instance type.

# %%
# Run this cell
# Initialize the variables appropriately. 
# Number of nodes in the cluster.
num_nodes=4

# Give a cluster name
slice_name='cluster_gpu_2'

# Make it True if you want to include persistence storage to a single node. KEEP IT FALSE FOR THE TIME BEING.
storage=False

# get attached to the cluster. By default adding NVMe is false.
add_NVMe = False

# Make it True if you want to include GPUs to different nodes in the cluster [depends on availability].
add_gpu=False

# By default master node will not have GPUs in it. For CPU only cluster False means lower resources then the workers.
master_gpu=False

# If only t4 gpu needs to be added.
add_t4=True

# If only rtx gpu needs to be added.
add_rtx=True

# Site name, pick one site from the above list of resources.
site='UTAH'

# Select node resource:- It follows the pattern fabric.c#N.m#N.d#N , where c:cores, m:primary memory, d:disk and #N: capacity.
# eg: fabric.c4.m8.d50 means cores:4, Memory:8Gb, disk:50Gb  
# List of node instance type is provided in - https://github.com/fabric-testbed/InformationModel/blob/master/fim/slivers/data/instance_sizes.json
instance_worker='fabric.c6.m16.d100'

# The resources of master node. It is better to be less than the worker nodes.
instance_master='fabric.c4.m8.d500'

# Operation system, Linux distribution e.g. default_ubuntu_18, default_ubuntu_20, etc.
image='default_ubuntu_18'

# %%
import pandas as pd

try:
    json_format=fablib.list_sites(output='json',quiet=True)
except Exception as e:
    print(f"Exception: {e}")

sites_df=pd.read_json(json_format)
site_df=sites_df[sites_df['name']==site]
type_t4=site_df['tesla_t4_available'].values
type_rtx=site_df['rtx6000_available'].values
nvme_available=site_df['nvme_available'].values
print("Number of Nvidia t4 available now at",site,"is:", type_t4[0])
print("Number of Nvidia rtx6000 available now at",site,"is:", type_rtx[0])
print("Number of NVMe available now at",site,"is:", nvme_available[0])

max_type_t4 = type_t4[0]
max_type_rtx = type_rtx[0]
total_gpus = max_type_t4 + max_type_rtx
# Out:
# Number of Nvidia t4 available now at UTAH is: 4
# Number of Nvidia rtx6000 available now at UTAH is: 5
# Number of NVMe available now at UTAH is: 13

# %%
# The max available GPU for the chosen site is mentioned above, to change it please make changes to the variables below.
# By default initialized with the available GPUs for the site.

#custom_number_of_t4 = max_type_t4
#custom_number_of_rtx = max_type_rtx

custom_number_of_t4 = 1
custom_number_of_rtx = 2

if custom_number_of_t4 < max_type_t4 or custom_number_of_rtx < max_type_rtx:
    max_type_t4 = custom_number_of_t4
    max_type_rtx = custom_number_of_rtx
    total_gpus = max_type_t4 + max_type_rtx
print(total_gpus)
gpu_names=[]

for i in range(1,total_gpus+1):
    gpu_names.append("GPU_{0}".format(i))
 
print(gpu_names)
temp_t4=max_type_t4
temp_rtx=max_type_rtx

######################################################
#####                  NVMe                      #####
######################################################

# Assumption: If the number of available NVMes' are less than the number of cluster node minus the master NVMes' will not

if nvme_available >= num_nodes-1 and add_NVMe == True:
    add_NVMe = True
print(add_NVMe)
# Out:
# 3
# ['GPU_1', 'GPU_2', 'GPU_3']
# False

# %%
# Run this cell

node_names=[]
nic_names=[]
iface_names=[]
nvme_names=[]
network_name='cluster_network'
storage_name = 'gaf-storage'


for i in range(1,num_nodes+1):
    node_names.append("Node{0}".format(i))
    nic_names.append("Nic{0}".format(i))
    iface_names.append("iface{0}".format(i))
    nvme_names.append("nvme{0}".format(i))

print(node_names)
print(nic_names)
print(iface_names)
print(nvme_names)
# Out:
# ['Node1', 'Node2', 'Node3', 'Node4']
# ['Nic1', 'Nic2', 'Nic3', 'Nic4']
# ['iface1', 'iface2', 'iface3', 'iface4']
# ['nvme1', 'nvme2', 'nvme3', 'nvme4']

# %%
# Only run when persistence storage needed to be attached. 
if storage == True:
    import traceback
    from plugins import Plugins
    try:
        Plugins.load()
    except Exception as e:
        traceback.print_exc()

# %%
# Run this cell, Visit the link below to find different instance type options. 
# Read the comments carefully given below and make changes as necessary. 

try:
    slice=fablib.new_slice(name=slice_name)
    
    for i in range(num_nodes):
        if master_gpu == False and i == 0:
            node=slice.add_node(name=node_names[i],
                                site=site, 
                                instance_type=instance_master,
                                image=image)
            iface_names[i]=node.add_component(model='NIC_Basic', name=node_names[i]).get_interfaces()[0]
        
        else:
            node=slice.add_node(name=node_names[i],
                                site=site,
                                instance_type=instance_worker,
                                image=image)
            iface_names[i]=node.add_component(model='NIC_Basic',name=node_names[i]).get_interfaces()[0]
            
            if add_gpu == True:
                if add_t4 == True and temp_t4 > 0:
                    node.add_component(model='GPU_TeslaT4', name=gpu_names[i-1])
                    temp_t4 = temp_t4 - 1
                elif add_rtx == True and temp_rtx >0 and temp_t4 <=0:
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
                    temp_rtx = temp_rtx - 1
            if add_NVMe == True:
                node.add_component(model='NVME_P4510', name=nvme_names[i-1])

except Exception as e:
    print(f'Exception: {e}')

# %%
# Run this cell
try:
    net_cluster=slice.add_l2network(name=network_name, interfaces=iface_names[:])
except Exception as e:
    print(f"Exception: {e}")

# %%
# Run this cell
# If this cell get executed successfully then IP address of the nodes will be displayed which can be used to ssh into the respective nodes.
# If there is an error while creating the slice/cluster, repeat from the third code cell block.

try:
    slice.submit()
except Exception as e:
    print(f'Exception: {e}')
# Out:
# Retry: 7, Time: 244 sec
# <style type="text/css">
# #T_c8409 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_c8409 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_c8409 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_c8409_row0_col0, #T_c8409_row0_col1, #T_c8409_row1_col0, #T_c8409_row1_col1, #T_c8409_row2_col0, #T_c8409_row2_col1, #T_c8409_row3_col0, #T_c8409_row3_col1, #T_c8409_row4_col0, #T_c8409_row4_col1, #T_c8409_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_c8409_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_c8409">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c8409_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_c8409_row0_col1" class="data row0 col1" >61b888dc-2957-41c6-9965-dd93024ddcd3</td>
#     </tr>
#     <tr>
#       <td id="T_c8409_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_c8409_row1_col1" class="data row1 col1" >cluster_gpu_2</td>
#     </tr>
#     <tr>
#       <td id="T_c8409_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_c8409_row2_col1" class="data row2 col1" >2023-04-26 00:25:05 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_c8409_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_c8409_row3_col1" class="data row3 col1" >2023-04-25 00:25:06 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_c8409_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_c8409_row4_col1" class="data row4 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_c8409_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_c8409_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4209d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_4209d th {
#   text-align: left;
# }
# #T_4209d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4209d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4209d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4209d_row0_col0, #T_4209d_row0_col1, #T_4209d_row0_col2, #T_4209d_row0_col3, #T_4209d_row0_col4, #T_4209d_row0_col5, #T_4209d_row0_col6, #T_4209d_row0_col7, #T_4209d_row0_col8, #T_4209d_row0_col9, #T_4209d_row0_col10, #T_4209d_row0_col13, #T_4209d_row0_col14, #T_4209d_row0_col15, #T_4209d_row1_col0, #T_4209d_row1_col1, #T_4209d_row1_col2, #T_4209d_row1_col3, #T_4209d_row1_col4, #T_4209d_row1_col5, #T_4209d_row1_col6, #T_4209d_row1_col7, #T_4209d_row1_col8, #T_4209d_row1_col9, #T_4209d_row1_col10, #T_4209d_row1_col13, #T_4209d_row1_col14, #T_4209d_row1_col15, #T_4209d_row2_col0, #T_4209d_row2_col1, #T_4209d_row2_col2, #T_4209d_row2_col3, #T_4209d_row2_col4, #T_4209d_row2_col5, #T_4209d_row2_col6, #T_4209d_row2_col7, #T_4209d_row2_col8, #T_4209d_row2_col9, #T_4209d_row2_col10, #T_4209d_row2_col13, #T_4209d_row2_col14, #T_4209d_row2_col15, #T_4209d_row3_col0, #T_4209d_row3_col1, #T_4209d_row3_col2, #T_4209d_row3_col3, #T_4209d_row3_col4, #T_4209d_row3_col5, #T_4209d_row3_col6, #T_4209d_row3_col7, #T_4209d_row3_col8, #T_4209d_row3_col9, #T_4209d_row3_col10, #T_4209d_row3_col13, #T_4209d_row3_col14, #T_4209d_row3_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_4209d_row0_col11, #T_4209d_row1_col11, #T_4209d_row2_col11, #T_4209d_row3_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_4209d_row0_col12, #T_4209d_row1_col12, #T_4209d_row2_col12, #T_4209d_row3_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_4209d">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_4209d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_4209d_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_4209d_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_4209d_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_4209d_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_4209d_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_4209d_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_4209d_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_4209d_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_4209d_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_4209d_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_4209d_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_4209d_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_4209d_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_4209d_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_4209d_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4209d_row0_col0" class="data row0 col0" >80cf3d6a-6bb2-4220-a8a0-e060883f7a3e</td>
#       <td id="T_4209d_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_4209d_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_4209d_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_4209d_row0_col4" class="data row0 col4" >500</td>
#       <td id="T_4209d_row0_col5" class="data row0 col5" >default_ubuntu_18</td>
#       <td id="T_4209d_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_4209d_row0_col7" class="data row0 col7" >utah-w5.fabric-testbed.net</td>
#       <td id="T_4209d_row0_col8" class="data row0 col8" >UTAH</td>
#       <td id="T_4209d_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_4209d_row0_col10" class="data row0 col10" >2001:1948:417:7:f816:3eff:fe4d:2418</td>
#       <td id="T_4209d_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_4209d_row0_col12" class="data row0 col12" ></td>
#       <td id="T_4209d_row0_col13" class="data row0 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_4209d_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_4209d_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_4209d_row1_col0" class="data row1 col0" >cafd7119-eb1f-4b0e-9c96-b08f91af945f</td>
#       <td id="T_4209d_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_4209d_row1_col2" class="data row1 col2" >6</td>
#       <td id="T_4209d_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_4209d_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_4209d_row1_col5" class="data row1 col5" >default_ubuntu_18</td>
#       <td id="T_4209d_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_4209d_row1_col7" class="data row1 col7" >utah-w5.fabric-testbed.net</td>
#       <td id="T_4209d_row1_col8" class="data row1 col8" >UTAH</td>
#       <td id="T_4209d_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_4209d_row1_col10" class="data row1 col10" >2001:1948:417:7:f816:3eff:fee0:294c</td>
#       <td id="T_4209d_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_4209d_row1_col12" class="data row1 col12" ></td>
#       <td id="T_4209d_row1_col13" class="data row1 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_4209d_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_4209d_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_4209d_row2_col0" class="data row2 col0" >998f8386-1e64-40e0-8ccf-183469f51557</td>
#       <td id="T_4209d_row2_col1" class="data row2 col1" >Node3</td>
#       <td id="T_4209d_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_4209d_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_4209d_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_4209d_row2_col5" class="data row2 col5" >default_ubuntu_18</td>
#       <td id="T_4209d_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_4209d_row2_col7" class="data row2 col7" >utah-w5.fabric-testbed.net</td>
#       <td id="T_4209d_row2_col8" class="data row2 col8" >UTAH</td>
#       <td id="T_4209d_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_4209d_row2_col10" class="data row2 col10" >2001:1948:417:7:f816:3eff:fea9:2303</td>
#       <td id="T_4209d_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_4209d_row2_col12" class="data row2 col12" ></td>
#       <td id="T_4209d_row2_col13" class="data row2 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_4209d_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_4209d_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_4209d_row3_col0" class="data row3 col0" >cf3f9619-db2f-4f21-a711-613ac6585bb8</td>
#       <td id="T_4209d_row3_col1" class="data row3 col1" >Node4</td>
#       <td id="T_4209d_row3_col2" class="data row3 col2" >6</td>
#       <td id="T_4209d_row3_col3" class="data row3 col3" >16</td>
#       <td id="T_4209d_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_4209d_row3_col5" class="data row3 col5" >default_ubuntu_18</td>
#       <td id="T_4209d_row3_col6" class="data row3 col6" >qcow2</td>
#       <td id="T_4209d_row3_col7" class="data row3 col7" >utah-w5.fabric-testbed.net</td>
#       <td id="T_4209d_row3_col8" class="data row3 col8" >UTAH</td>
# <style type="text/css">
# #T_8c2c2 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_8c2c2 th {
#   text-align: left;
# }
# #T_8c2c2 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8c2c2 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_8c2c2 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8c2c2_row0_col0, #T_8c2c2_row0_col1, #T_8c2c2_row0_col2, #T_8c2c2_row0_col3, #T_8c2c2_row0_col4, #T_8c2c2_row0_col5, #T_8c2c2_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_8c2c2_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_8c2c2_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_8c2c2">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_8c2c2_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_8c2c2_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_8c2c2_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_8c2c2_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_8c2c2_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_8c2c2_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_8c2c2_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_8c2c2_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_8c2c2_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8c2c2_row0_col0" class="data row0 col0" >805a7cb8-cfbf-4a2d-89a0-0a76a702374b</td>
#       <td id="T_8c2c2_row0_col1" class="data row0 col1" >cluster_network</td>
#       <td id="T_8c2c2_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_8c2c2_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_8c2c2_row0_col4" class="data row0 col4" >UTAH</td>
#       <td id="T_8c2c2_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_8c2c2_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_8c2c2_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_8c2c2_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# Time to stable 244 seconds
# Running post_boot_config ... Time to post boot config 262 seconds
# <style type="text/css">
# #T_0553b caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0553b th {
#   text-align: left;
# }
# #T_0553b tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0553b tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0553b .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0553b_row0_col0, #T_0553b_row0_col1, #T_0553b_row0_col2, #T_0553b_row0_col3, #T_0553b_row0_col4, #T_0553b_row0_col5, #T_0553b_row0_col6, #T_0553b_row0_col7, #T_0553b_row1_col0, #T_0553b_row1_col1, #T_0553b_row1_col2, #T_0553b_row1_col3, #T_0553b_row1_col4, #T_0553b_row1_col5, #T_0553b_row1_col6, #T_0553b_row1_col7, #T_0553b_row2_col0, #T_0553b_row2_col1, #T_0553b_row2_col2, #T_0553b_row2_col3, #T_0553b_row2_col4, #T_0553b_row2_col5, #T_0553b_row2_col6, #T_0553b_row2_col7, #T_0553b_row3_col0, #T_0553b_row3_col1, #T_0553b_row3_col2, #T_0553b_row3_col3, #T_0553b_row3_col4, #T_0553b_row3_col5, #T_0553b_row3_col6, #T_0553b_row3_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_0553b">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_0553b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_0553b_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_0553b_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_0553b_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_0553b_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_0553b_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_0553b_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_0553b_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0553b_row0_col0" class="data row0 col0" >Node1-Node1-p1</td>
#       <td id="T_0553b_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_0553b_row0_col2" class="data row0 col2" >cluster_network</td>
#       <td id="T_0553b_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_0553b_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_0553b_row0_col5" class="data row0 col5" >02:AA:1F:20:41:A6</td>
#       <td id="T_0553b_row0_col6" class="data row0 col6" >ens7</td>
#       <td id="T_0553b_row0_col7" class="data row0 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_0553b_row1_col0" class="data row1 col0" >Node2-Node2-p1</td>
#       <td id="T_0553b_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_0553b_row1_col2" class="data row1 col2" >cluster_network</td>
#       <td id="T_0553b_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_0553b_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_0553b_row1_col5" class="data row1 col5" >02:B1:1B:7C:97:2E</td>
#       <td id="T_0553b_row1_col6" class="data row1 col6" >ens7</td>
#       <td id="T_0553b_row1_col7" class="data row1 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_0553b_row2_col0" class="data row2 col0" >Node3-Node3-p1</td>
#       <td id="T_0553b_row2_col1" class="data row2 col1" >Node3</td>
#       <td id="T_0553b_row2_col2" class="data row2 col2" >cluster_network</td>
#       <td id="T_0553b_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_0553b_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_0553b_row2_col5" class="data row2 col5" >02:13:80:A3:DC:9D</td>
#       <td id="T_0553b_row2_col6" class="data row2 col6" >ens7</td>
#       <td id="T_0553b_row2_col7" class="data row2 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_0553b_row3_col0" class="data row3 col0" >Node4-Node4-p1</td>
#       <td id="T_0553b_row3_col1" class="data row3 col1" >Node4</td>
#       <td id="T_0553b_row3_col2" class="data row3 col2" >cluster_network</td>
#       <td id="T_0553b_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_0553b_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_0553b_row3_col5" class="data row3 col5" >06:1F:9F:D4:E2:30</td>
#       <td id="T_0553b_row3_col6" class="data row3 col6" >ens7</td>
#       <td id="T_0553b_row3_col7" class="data row3 col7" >ens7</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 275 seconds

# %% [markdown]
# ## Step-3: Configuring the network and setting up the cluster

# %%
#Run this cell

from ipaddress import IPv4Address, IPv4Network

try:
    subnet=IPv4Network("192.168.1.0/24")
    available_ips=list(subnet)[1:]
except Exception as e:
    print(f"Exception: {e}")

# %%
#try:
#    for node in slice.get_nodes():
#        node_iface=node.get_interface(network_name=network_name)
#        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
#except Exception as e:
#    print(f"Exception: {e}")

# %%
#Run this cell
#%%capture
try:
    for node in slice.get_nodes():
        node_iface=node.get_interface(network_name=network_name)
        node_IP_addr=available_ips.pop(0)
        node_iface.ip_addr_add(addr=node_IP_addr, subnet=subnet)
        
        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
        _, _ = node.execute('sudo apt-get update')
        stdout, stderr = node.execute('sudo apt install net-tools')        
        stdout, stderr = node.execute(f'sudo ifconfig {node_iface.get_os_interface()} up')
        
        
except Exception as e:
    print(f"Exception: {e}")
# Out:
# 3: ens7: <BROADCAST,MULTICAST> mtu 1500 qdisc noop state DOWN group default qlen 1000
#     link/ether 02:aa:1f:20:41:a6 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.1/24 scope global ens7
#        valid_lft forever preferred_lft forever
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2634 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [8570 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe Translation-en [4941 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main Translation-en [455 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1207 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/restricted Translation-en [167 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1289 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe Translation-en [303 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [19.8 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/multiverse Translation-en [3928 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [151 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse Translation-en [108 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2967 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main Translation-en [542 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1237 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted Translation-en [172 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1900 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe Translation-en [416 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [25.6 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse Translation-en [6088 B]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [53.3 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main Translation-en [14.6 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [18.1 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe Translation-en [8668 B]
# Fetched 27.5 MB in 5s (5233 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Reading state information...
# net-tools is already the newest version (1.60+git20161116.90da8a0-1ubuntu1).
# net-tools set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 167 not upgraded.
# 3: ens7: <BROADCAST,MULTICAST> mtu 1500 qdisc noop state DOWN group default qlen 1000
#     link/ether 02:b1:1b:7c:97:2e brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.2/24 scope global ens7
#        valid_lft forever preferred_lft forever
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2634 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [8570 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe Translation-en [4941 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main Translation-en [455 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1207 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/restricted Translation-en [167 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1289 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe Translation-en [303 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [19.8 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/multiverse Translation-en [3928 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [151 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse Translation-en [108 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2967 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main Translation-en [542 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1237 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted Translation-en [172 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1900 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe Translation-en [416 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [25.6 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse Translation-en [6088 B]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [53.3 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main Translation-en [14.6 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [18.1 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe Translation-en [8668 B]
# Fetched 27.5 MB in 5s (5344 kB/s)
# Reading package lists...
# Reading package lists...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20161116.90da8a0-1ubuntu1).
# net-tools set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 167 not upgraded.
# 3: ens7: <BROADCAST,MULTICAST> mtu 1500 qdisc noop state DOWN group default qlen 1000
#     link/ether 02:13:80:a3:dc:9d brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.3/24 scope global ens7
#        valid_lft forever preferred_lft forever
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2634 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [8570 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe Translation-en [4941 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main Translation-en [455 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1207 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/restricted Translation-en [167 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1289 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe Translation-en [303 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [19.8 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/multiverse Translation-en [3928 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [151 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse Translation-en [108 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2967 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main Translation-en [542 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1237 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted Translation-en [172 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1900 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe Translation-en [416 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [25.6 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse Translation-en [6088 B]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [53.3 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main Translation-en [14.6 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [18.1 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe Translation-en [8668 B]
# Fetched 27.5 MB in 5s (5326 kB/s)
# Reading package lists...
# Reading package lists...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Building dependency tree...
# Reading state information...
# net-tools is already the newest version (1.60+git20161116.90da8a0-1ubuntu1).
# net-tools set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 167 not upgraded.
# 3: ens7: <BROADCAST,MULTICAST> mtu 1500 qdisc noop state DOWN group default qlen 1000
#     link/ether 06:1f:9f:d4:e2:30 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.4/24 scope global ens7
#        valid_lft forever preferred_lft forever
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2634 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [8570 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/universe Translation-en [4941 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main Translation-en [455 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1207 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/restricted Translation-en [167 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1289 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe Translation-en [303 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [19.8 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/multiverse Translation-en [3928 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [151 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu bionic/multiverse Translation-en [108 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2967 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/main Translation-en [542 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1237 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/restricted Translation-en [172 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1900 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/universe Translation-en [416 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [25.6 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-updates/multiverse Translation-en [6088 B]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [53.3 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/main Translation-en [14.6 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [18.1 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu bionic-backports/universe Translation-en [8668 B]
# Fetched 27.5 MB in 5s (5349 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Reading state information...
# net-tools is already the newest version (1.60+git20161116.90da8a0-1ubuntu1).
# net-tools set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 167 not upgraded.

# %%
#Run this cell
# If the ping is successful, that means the nodes are connected properly if there is any error then may need to recreate the cluster or further have to look into it. 

try:
    node1=slice.get_node(name='Node1')
    
    stdout,stderr=node1.execute(f' ping -c 3 192.168.1.4')
    print(stdout)
    print(stderr)
    
except Exception as e:
    print(f'Exception: {e}')
# Out:
# PING 192.168.1.4 (192.168.1.4) 56(84) bytes of data.
# 64 bytes from 192.168.1.4: icmp_seq=1 ttl=64 time=0.361 ms
# 64 bytes from 192.168.1.4: icmp_seq=2 ttl=64 time=0.080 ms
# 64 bytes from 192.168.1.4: icmp_seq=3 ttl=64 time=0.107 ms
#
# --- 192.168.1.4 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2028ms
# rtt min/avg/max/mdev = 0.080/0.182/0.361/0.127 ms
# PING 192.168.1.4 (192.168.1.4) 56(84) bytes of data.
# 64 bytes from 192.168.1.4: icmp_seq=1 ttl=64 time=0.361 ms
# 64 bytes from 192.168.1.4: icmp_seq=2 ttl=64 time=0.080 ms
# 64 bytes from 192.168.1.4: icmp_seq=3 ttl=64 time=0.107 ms
#
# --- 192.168.1.4 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2028ms
# rtt min/avg/max/mdev = 0.080/0.182/0.361/0.127 ms

# %%
# Run this cell
# Function to create a file that contains IPs and hostnames related to it.

def append_line(file_path,text):
    with open(file_path,"a+") as file_des:
        file_des.seek(0)
        data=file_des.read(-1)
        if len(data)>0:
            file_des.write("\n")
        file_des.write(text)

# %%
# Run this cell

import os

if os.path.isfile('/home/fabric/work/hosts') or os.path.isfile('/home/fabric/work/ips.txt') or os.path.isfile('/home/fabric/work/workers'):
    os.system("rm /home/fabric/work/hosts")
    os.system("rm /home/fabric/work/ips.txt")
    os.system("rm /home/fabric/work/workers")    
else:
    print("does not exist")

if os.path.isfile('/home/fabric/work/gpu_ips.txt'):
    os.system("rm /home/fabric/work/gpu_ips.txt")
    
#os.system("rm /home/fabric/work/ips.txt")

# %%
# Run this cell

# Capturing the IP addresses, this step needs to be integrated with the IP assigning stage, coded above. Or it may stay independent.
import os

i=1
local_host="127.0.0.1 localhost"
path_to_host_file="/home/fabric/work/hosts"
path_to_ip_file="/home/fabric/work/ips.txt"
path_to_worker_ip="/home/fabric/work/workers"
path_to_gpu_ips="/home/fabric/work/gpu_ips.txt"
gpu_name="NVIDIA"

append_line(path_to_host_file,local_host)

try:
    for node in slice.get_nodes():
        stdout, stderr=node.execute("hostname -I")
        IP=stdout.split(" ")[1]
        node_name="node{0}".format(i)
        vm_names="vm{0}".format(i-1)
        append_line(path_to_ip_file,IP)
        
        stdout, stderr=node.execute("hostname")
        line=IP+" "+node_name+" "+vm_names+" "+stdout
        append_line(path_to_host_file,line)
      
    
        if(i>1):
            append_line(path_to_worker_ip,vm_names)
            #append_line(path_to_worker_ip,IP)
        
        print(line)
        print(stderr)
        
        stdout_gpu, _=node.execute('lspci | grep NVIDIA')   
        if gpu_name in stdout_gpu:
            stdout_ip, _=node.execute('hostname -I')
            ip=stdout_ip.split(" ")[1]
            append_line(path_to_gpu_ips,ip)
            #print(ip)
        
        i=i+1
except Exception as e:
    print(f"Exception: {e}")
    
print(IP)
# Out:
# 10.20.5.154 192.168.1.1 2001:1948:417:7:f816:3eff:fe4d:2418
# 80cf3d6a-6bb2-4220-a8a0-e060883f7a3e-node1
# 192.168.1.1 node1 vm0 80cf3d6a-6bb2-4220-a8a0-e060883f7a3e-node1
#
#
# 10.20.5.171 192.168.1.2 2001:1948:417:7:f816:3eff:fee0:294c
# cafd7119-eb1f-4b0e-9c96-b08f91af945f-node2
# 192.168.1.2 node2 vm1 cafd7119-eb1f-4b0e-9c96-b08f91af945f-node2
#
#
# 10.20.5.196 192.168.1.3 2001:1948:417:7:f816:3eff:fea9:2303
# 998f8386-1e64-40e0-8ccf-183469f51557-node3
# 192.168.1.3 node3 vm2 998f8386-1e64-40e0-8ccf-183469f51557-node3
#
#
# 10.20.5.146 192.168.1.4 2001:1948:417:7:f816:3eff:fe76:4cbf
# cf3f9619-db2f-4f21-a711-613ac6585bb8-node4
# 192.168.1.4 node4 vm3 cf3f9619-db2f-4f21-a711-613ac6585bb8-node4
#
#
# 192.168.1.4

# %%
# Run this cell

try:
    for node in slice.get_nodes():
        stdout, stderr=node.execute(f'sudo cp /etc/hosts /etc/hosts_backup') # if you run the command twice the back up will be overwritten, a conditional block should be written
        output_host_copy=node.upload_file(path_to_host_file,"/home/ubuntu/hosts")
        output_ip_copy=node.upload_file(path_to_ip_file,"/home/ubuntu/ips.txt")
        output_worker_copy=node.upload_file(path_to_worker_ip,"/home/ubuntu/workers")
        stdout_host_copy,stderr_host_copy=node.execute(f'sudo cp /home/ubuntu/hosts /etc/hosts')
        if os.path.isfile('/home/fabric/work/gpu_ips.txt'):
            output_gpu_copy=node.upload_file(path_to_gpu_ips,"/home/ubuntu/gpu_ips.txt")
        
        print(stderr)
        print(stderr_host_copy)
except Exception as e:
    print(f"Exception : {e}")

# %%
# Run this cell

import os

output=os.system('ssh-keygen -q -t rsa -N "" -f /home/fabric/work/id_rsa > /dev/null 2>&1')

# %%
# Run this cell

try:
    for node in slice.get_nodes():
        output_private=node.upload_file("/home/fabric/work/id_rsa","/home/ubuntu/.ssh/id_rsa")
        output_public=node.upload_file("/home/fabric/work/id_rsa.pub","/home/ubuntu/.ssh/id_rsa.pub")
        
        stdout, stderr=node.execute(f' cat /home/ubuntu/.ssh/id_rsa.pub >> /home/ubuntu/.ssh/authorized_keys')
        stdout, stderr=node.execute(f' chmod 600 /home/ubuntu/.ssh/id_rsa*')
        
        print(output_private)
        print(output_public)
        print(stderr)
        #print(stdout)
        
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -rw-rw-r--   1 1000     1000         2643 25 Apr 00:33 ?
# -rw-rw-r--   1 1000     1000          601 25 Apr 00:33 ?
#
# -rw-rw-r--   1 1000     1000         2643 25 Apr 00:33 ?
# -rw-rw-r--   1 1000     1000          601 25 Apr 00:34 ?
#
# -rw-rw-r--   1 1000     1000         2643 25 Apr 00:34 ?
# -rw-rw-r--   1 1000     1000          601 25 Apr 00:34 ?
#
# -rw-rw-r--   1 1000     1000         2643 25 Apr 00:34 ?
# -rw-rw-r--   1 1000     1000          601 25 Apr 00:34 ?

# %%
# Run this cell. This is the last cell to run. Please read the comments in the next few cells to know how to extend the lease time and how to delete a slice/cluster. 

from ipaddress import ip_address, IPv6Address
try:
    for node in slice.get_nodes():
        if type(ip_address(node.get_management_ip())) is IPv6Address:
            node.upload_file("/home/fabric/work/nat64.sh", "/home/ubuntu/nat64.sh")
            #stdout, stderr=node.execute(f' chmod +x /home/ubuntu/nat64.sh && sudo bash /home/ubuntu/nat64.sh')
            stdout, stderr=node.execute(f' chmod +x /home/ubuntu/nat64.sh && sudo bash /home/ubuntu/nat64.sh > /dev/null 2>&1')
            
            print(stdout)
            print(stderr)
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step-4: Deleting and extending lease of a slice

# %%
# Run this cell ONLY when you want to delete the cell
# To delete a slice/cluster.
try:
    slice=fablib.get_slice(name="cluster_gatk") # Put the cluster name that you want to delete
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: Failed to delete slice: Status.FAILURE, (500)
# Reason: INTERNAL SERVER ERROR
# HTTP response headers: HTTPHeaderDict({'Server': 'nginx/1.21.6', 'Date': 'Wed, 25 Jan 2023 15:37:01 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '274', 'Connection': 'keep-alive', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'DNT, User-Agent, X-Requested-With, If-Modified-Since, Cache-Control, Content-Type, Range, Authorization', 'Access-Control-Allow-Methods': 'GET, POST, PUT, PATCH, DELETE, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'Content-Length, Content-Range, X-Error', 'X-Error': 'Unable to delete Slice# 23cff7cb-6671-4d17-b2d6-3ef79348a03b that is not yet stable, try again later'})
# HTTP response body: b'{\n    "errors": [\n        {\n            "details": "Unable to delete Slice# 23cff7cb-6671-4d17-b2d6-3ef79348a03b that is not yet stable, try again later",\n            "message": "Internal Server Error"\n        }\n    ],\n    "size": 1,\n    "status": 500,\n    "type": "error"\n}'

# %%
# Run this cell ONLY when you want to exted the time of the slice. Or to extend the lease time of the slice/cluster.

import datetime
slice_name='cluster_exp' # Give the cluster/slice name that you want to extend

#Set end host to now plus 1 day
new_end_date = (datetime.datetime.utcnow() + datetime.timedelta(days=7)).strftime("%Y-%m-%d %H:%M:%S %z")
#new_end_date = (datetime.now(timezone.utc) + timedelta(days=6)).strftime("%Y-%m-%d %H:%M:%S %z")
print(type(new_end_date), new_end_date)
try:
    slice=fablib.get_slice(name=slice_name)
    slice.renew('2023-05-06 18:04:26 +0000') # Give the new lease end date and time of the slice. One can increase it by 7 days from the day of creation of the slice/cluster. 
    
    #print(f"Lease End (UTC)        : {slice.get_lease_end()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <class 'str'> 2023-05-01 23:14:15

# %%
# Run this cell ONLY to observe the new lease time.

slice_name='cluster_exp' # Give the slice/cluster name that you just extended. 
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------  ------------------------------------
# Slice Name   cluster_exp
# Slice ID     6f79613e-46f0-4323-8f04-395221080b2e
# Slice State  StableOK
# Lease End    2023-05-06 18:04:26 +0000
# -----------  ------------------------------------

# %%
# Run this cell ONLY to observe the new lease time.

slice_name='cluster_gpu' # Give the slice/cluster name that you just extended. 
try:
    slice = fablib.get_slice(name=slice_name)
    gpu_name="NVIDIA"
    for node in slice.get_nodes():
        #stdout, stderr=node.execute(f'sudo cp /etc/hosts /etc/hosts_backup') # if you run the command twice the back up will be overwritten, a conditional block should be written
        stdout_gpu, _=node.execute('lspci | grep NVIDIA')   
        if gpu_name in stdout_gpu:
            stdout_ip, _=node.execute('hostname -I')
            ip=stdout_ip.split(" ")[1]
            print(ip)
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Do not bother about the code below !!! ;-)

# %%
# Do not Run this cell

storage_name = 'gaf-storage1'

node1=slice.get_node(name='Node1')
node1.add_component(model='NVME_P4510',name='gaf-storage')
# Out:
# ---------------------------------------------------------------------------
# TopologyException                         Traceback (most recent call last)
# /tmp/ipykernel_55/829870909.py in <module>
#       2
#       3 node1=slice.get_node(name='Node1')
# ----> 4 node1.add_component(model='NVME_P4510',name='gaf-storage')
#
# /opt/conda/lib/python3.9/site-packages/fabrictestbed_extensions/fablib/node.py in add_component(self, model, name)
#     517         :rtype: Component
#     518         """
# --> 519         return Component.new_component(node=self, model=model, name=name)
#     520
#     521     def get_components(self) -> List[Component]:
#
# /opt/conda/lib/python3.9/site-packages/fabrictestbed_extensions/fablib/component.py in new_component(node, model, name)
#     120         name = Component.calculate_name(node=node, name=name)
#     121
# --> 122         return Component(node=node, fim_component=node.fim_node.add_component(
#     123             model_type=Component.component_model_map[model], name=name))
#     124
#
# /opt/conda/lib/python3.9/site-packages/fim/user/node.py in add_component(self, name, node_id, ctype, model, model_type, network_service_node_id, interface_node_ids, interface_labels, **kwargs)
#     277         # make sure name is unique within the node
#     278         if name in self.__list_components().keys():
# --> 279             raise TopologyException('Component names must be unique within node.')
#     280         # add component node and populate properties
#     281         c = Component(name=name, node_id=node_id, topo=self.topo, etype=ElementType.NEW,
#
# TopologyException: Component names must be unique within node.

# %%
slice_name='cluster_gatk'

try:
    slice=fablib.get_slice(name=slice_name)
except Exception as e:
    print(f"Exception: {e}")

# %%
# Do not run this cell, only for experimentation.

try:
    node = slice.get_node(name='Node4')
    print(f"{node}")
    storage = node.get_storage(name='gaf-storage')
    print(f"{storage}")
    print(f"Storage Device Name: {storage.get_device_name()}")
    #print("Mounting the storage volume")
    #stdout, stderr = node.execute(f"sudo mkdir -p /mnt/{storage_name};"
                                 # f"sudo mount {storage.get_device_name()} /mnt/{storage_name}")
    print(stdout)
    print(stderr)
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# ID                 342cfbfa-8e20-4e69-992a-64364d08db35
# Name               Node4
# Cores              4
# RAM                8
# Disk               10
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               star-w2.fabric-testbed.net
# Site               STAR
# Management IP      2001:400:a100:3030:f816:3eff:fe08:a7d4
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -J mjdbz4_0000018266@bastion-1.fabric-testbed.net ubuntu@2001:400:a100:3030:f816:3eff:fe08:a7d4
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# -----------  --------------------
# Name         gaf-storage
# Details      Site-local NAS share
# Disk (G)     0
# Units        1
# PCI Address
# Model
# Type         Storage
# -----------  --------------------
# Storage Device Name: /dev/vdb
#
# mount: /mnt/gaf-storage: wrong fs type, bad option, bad superblock on /dev/vdb, missing codepage or helper program, or other error.

# %%
hosts=[]
import random
randomList=[]

while True:
    r=random.randint(1,9)
    
    if r not in randomList:
        randomList.append(r)
    if len(randomList) == 8:
        break
        
for i in range(1,num_nodes+1):
    hosts.append("{0}-w{1}.fabric-testbed.net".format(site.lower(),randomList[i-1]))
    
print(hosts)

# %%
try:
    node = slice.get_node('Node3') 
    #node.show()

    nvme1 = node.get_component(nvme_names[1])
    nvme1.show()
    nvme1.configure_nvme()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_6d212 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6d212 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6d212 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_6d212_row0_col0, #T_6d212_row0_col1, #T_6d212_row1_col0, #T_6d212_row1_col1, #T_6d212_row2_col0, #T_6d212_row2_col1, #T_6d212_row3_col0, #T_6d212_row3_col1, #T_6d212_row4_col0, #T_6d212_row4_col1, #T_6d212_row5_col0, #T_6d212_row5_col1, #T_6d212_row6_col0, #T_6d212_row6_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_6d212">
#   <caption>Component</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d212_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_6d212_row0_col1" class="data row0 col1" >Node3-nvme2</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row1_col0" class="data row1 col0" >Details</td>
#       <td id="T_6d212_row1_col1" class="data row1 col1" >Dell Express Flash NVMe P4510 1TB SFF</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row2_col0" class="data row2 col0" >Disk</td>
#       <td id="T_6d212_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row3_col0" class="data row3 col0" >Units</td>
#       <td id="T_6d212_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row4_col0" class="data row4 col0" >PCI Address</td>
#       <td id="T_6d212_row4_col1" class="data row4 col1" >['0000:00:08.0']</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row5_col0" class="data row5 col0" >Model</td>
#       <td id="T_6d212_row5_col1" class="data row5 col1" >NVME_P4510</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row6_col0" class="data row6 col0" >Type</td>
#       <td id="T_6d212_row6_col1" class="data row6 col1" >NVME</td>
#     </tr>
#   </tbody>
# </table>
# Disk /dev/nvme0n1: 894.3 GiB, 960197124096 bytes, 1875385008 sectors
# Units: sectors of 1 * 512 = 512 bytes
# Sector size (logical/physical): 512 bytes / 512 bytes
# I/O size (minimum/optimal): 512 bytes / 512 bytes
#  fdisk: cannot open /dev/nvme0: Illegal seek
#  config_nvme Fail: Node3-nvme2
# Exception: []

# %%
nvme_names[1]
# Out:
# 'nvme2'
