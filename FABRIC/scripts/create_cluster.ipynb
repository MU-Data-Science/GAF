# %% [markdown]
# # Creating a cluster/slice

# %% [markdown]
# ## Please read carefully all the instructions. Specially the comments given in each cell. These comments are pertinent to run a cluster successfully.
#
# If the fabric environment is not set please read through the topic <code>FABRIC Environment Setup</code> in <code>start_here.ipynb</code> notebook given under <code>jupyter-example</code> folder in fabric's JupyterHub.
#
# <b> At first read the comments in the cell and then only run the cell. </b>

# %% [markdown]
# ## STEP-1

# %%
# Run this cell.

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
                     
    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_6f64c tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6f64c tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6f64c caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_6f64c_row0_col0, #T_6f64c_row0_col1, #T_6f64c_row1_col0, #T_6f64c_row1_col1, #T_6f64c_row2_col0, #T_6f64c_row2_col1, #T_6f64c_row3_col0, #T_6f64c_row3_col1, #T_6f64c_row4_col0, #T_6f64c_row4_col1, #T_6f64c_row5_col0, #T_6f64c_row5_col1, #T_6f64c_row6_col0, #T_6f64c_row6_col1, #T_6f64c_row7_col0, #T_6f64c_row7_col1, #T_6f64c_row8_col0, #T_6f64c_row8_col1, #T_6f64c_row9_col0, #T_6f64c_row9_col1, #T_6f64c_row10_col0, #T_6f64c_row10_col1, #T_6f64c_row11_col0, #T_6f64c_row11_col1, #T_6f64c_row12_col0, #T_6f64c_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_6f64c">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6f64c_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_6f64c_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_6f64c_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_6f64c_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_6f64c_row3_col1" class="data row3 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_6f64c_row4_col1" class="data row4 col1" >khawar_shehzad_0000059894</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_6f64c_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/bastion</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_6f64c_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_6f64c_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_6f64c_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/sliver.pub</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_6f64c_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/sliver</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_6f64c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_6f64c_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_6f64c_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_6f64c_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Run this cell
# To find all the available resources at this time
#run the cell below for easier readability 
try:
    resources = fablib.list_sites()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_6cb08 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_6cb08 th {
#   text-align: left;
# }
# #T_6cb08 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6cb08 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6cb08 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6cb08_row0_col0, #T_6cb08_row0_col1, #T_6cb08_row0_col2, #T_6cb08_row0_col3, #T_6cb08_row0_col4, #T_6cb08_row0_col5, #T_6cb08_row0_col6, #T_6cb08_row0_col7, #T_6cb08_row0_col8, #T_6cb08_row0_col9, #T_6cb08_row0_col10, #T_6cb08_row0_col11, #T_6cb08_row0_col12, #T_6cb08_row0_col13, #T_6cb08_row0_col14, #T_6cb08_row0_col15, #T_6cb08_row0_col16, #T_6cb08_row0_col17, #T_6cb08_row0_col18, #T_6cb08_row0_col19, #T_6cb08_row0_col20, #T_6cb08_row0_col21, #T_6cb08_row0_col22, #T_6cb08_row0_col23, #T_6cb08_row0_col24, #T_6cb08_row0_col25, #T_6cb08_row0_col26, #T_6cb08_row0_col27, #T_6cb08_row0_col28, #T_6cb08_row0_col29, #T_6cb08_row0_col30, #T_6cb08_row0_col31, #T_6cb08_row1_col0, #T_6cb08_row1_col1, #T_6cb08_row1_col2, #T_6cb08_row1_col3, #T_6cb08_row1_col4, #T_6cb08_row1_col5, #T_6cb08_row1_col6, #T_6cb08_row1_col7, #T_6cb08_row1_col8, #T_6cb08_row1_col9, #T_6cb08_row1_col10, #T_6cb08_row1_col11, #T_6cb08_row1_col12, #T_6cb08_row1_col13, #T_6cb08_row1_col14, #T_6cb08_row1_col15, #T_6cb08_row1_col16, #T_6cb08_row1_col17, #T_6cb08_row1_col18, #T_6cb08_row1_col19, #T_6cb08_row1_col20, #T_6cb08_row1_col21, #T_6cb08_row1_col22, #T_6cb08_row1_col23, #T_6cb08_row1_col24, #T_6cb08_row1_col25, #T_6cb08_row1_col26, #T_6cb08_row1_col27, #T_6cb08_row1_col28, #T_6cb08_row1_col29, #T_6cb08_row1_col30, #T_6cb08_row1_col31, #T_6cb08_row2_col0, #T_6cb08_row2_col1, #T_6cb08_row2_col2, #T_6cb08_row2_col3, #T_6cb08_row2_col4, #T_6cb08_row2_col5, #T_6cb08_row2_col6, #T_6cb08_row2_col7, #T_6cb08_row2_col8, #T_6cb08_row2_col9, #T_6cb08_row2_col10, #T_6cb08_row2_col11, #T_6cb08_row2_col12, #T_6cb08_row2_col13, #T_6cb08_row2_col14, #T_6cb08_row2_col15, #T_6cb08_row2_col16, #T_6cb08_row2_col17, #T_6cb08_row2_col18, #T_6cb08_row2_col19, #T_6cb08_row2_col20, #T_6cb08_row2_col21, #T_6cb08_row2_col22, #T_6cb08_row2_col23, #T_6cb08_row2_col24, #T_6cb08_row2_col25, #T_6cb08_row2_col26, #T_6cb08_row2_col27, #T_6cb08_row2_col28, #T_6cb08_row2_col29, #T_6cb08_row2_col30, #T_6cb08_row2_col31, #T_6cb08_row3_col0, #T_6cb08_row3_col1, #T_6cb08_row3_col2, #T_6cb08_row3_col3, #T_6cb08_row3_col4, #T_6cb08_row3_col5, #T_6cb08_row3_col6, #T_6cb08_row3_col7, #T_6cb08_row3_col8, #T_6cb08_row3_col9, #T_6cb08_row3_col10, #T_6cb08_row3_col11, #T_6cb08_row3_col12, #T_6cb08_row3_col13, #T_6cb08_row3_col14, #T_6cb08_row3_col15, #T_6cb08_row3_col16, #T_6cb08_row3_col17, #T_6cb08_row3_col18, #T_6cb08_row3_col19, #T_6cb08_row3_col20, #T_6cb08_row3_col21, #T_6cb08_row3_col22, #T_6cb08_row3_col23, #T_6cb08_row3_col24, #T_6cb08_row3_col25, #T_6cb08_row3_col26, #T_6cb08_row3_col27, #T_6cb08_row3_col28, #T_6cb08_row3_col29, #T_6cb08_row3_col30, #T_6cb08_row3_col31, #T_6cb08_row4_col0, #T_6cb08_row4_col1, #T_6cb08_row4_col2, #T_6cb08_row4_col3, #T_6cb08_row4_col4, #T_6cb08_row4_col5, #T_6cb08_row4_col6, #T_6cb08_row4_col7, #T_6cb08_row4_col8, #T_6cb08_row4_col9, #T_6cb08_row4_col10, #T_6cb08_row4_col11, #T_6cb08_row4_col12, #T_6cb08_row4_col13, #T_6cb08_row4_col14, #T_6cb08_row4_col15, #T_6cb08_row4_col16, #T_6cb08_row4_col17, #T_6cb08_row4_col18, #T_6cb08_row4_col19, #T_6cb08_row4_col20, #T_6cb08_row4_col21, #T_6cb08_row4_col22, #T_6cb08_row4_col23, #T_6cb08_row4_col24, #T_6cb08_row4_col25, #T_6cb08_row4_col26, #T_6cb08_row4_col27, #T_6cb08_row4_col28, #T_6cb08_row4_col29, #T_6cb08_row4_col30, #T_6cb08_row4_col31, #T_6cb08_row5_col0, #T_6cb08_row5_col1, #T_6cb08_row5_col2, #T_6cb08_row5_col3, #T_6cb08_row5_col4, #T_6cb08_row5_col5, #T_6cb08_row5_col6, #T_6cb08_row5_col7, #T_6cb08_row5_col8, #T_6cb08_row5_col9, #T_6cb08_row5_col10, #T_6cb08_row5_col11, #T_6cb08_row5_col12, #T_6cb08_row5_col13, #T_6cb08_row5_col14, #T_6cb08_row5_col15, #T_6cb08_row5_col16, #T_6cb08_row5_col17, #T_6cb08_row5_col18, #T_6cb08_row5_col19, #T_6cb08_row5_col20, #T_6cb08_row5_col21, #T_6cb08_row5_col22, #T_6cb08_row5_col23, #T_6cb08_row5_col24, #T_6cb08_row5_col25, #T_6cb08_row5_col26, #T_6cb08_row5_col27, #T_6cb08_row5_col28, #T_6cb08_row5_col29, #T_6cb08_row5_col30, #T_6cb08_row5_col31, #T_6cb08_row6_col0, #T_6cb08 ...
# <pandas.io.formats.style.Styler object at 0x7f67c68e32b0>

# %%
##for easier readability of available resources
import pandas as pd 
pd.DataFrame(resources.data)[['Hosts','CPUs','Name','Cores Available','RAM Available','Tesla T4 Available','RTX6000 Available']]
# Out:
#     Hosts  CPUs    Name  Cores Available  RAM Available  Tesla T4 Available  \
# 0       0     0     SCM                0              0                   0
# 1       0     0    SEAT                0              0                   0
# 2       0     0    STAR                0              0                   6
# 3       0     0    RUTG                0              0                   0
# 4       0     0    TACC                0              0                   3
# 5       0     0     PSC                0              0                   0
# 6       0     0     MAX                0              0                   4
# 7       0     0    UTAH                0              0                   4
# 8       0     0    WASH                0              0                   2
# 9       0     0     FIU                0              0                   4
# 10      0     0    AL2S                0              0                   0
# 11      0     0    MICH                0              0                   2
# 12      0     0    NEWY                0              0                   0
# 13      0     0    PRIN                0              0                   0
# 14      0     0    MASS                0              0                   2
# 15      0     0    UCSD                0              0                   4
# 16      0     0    LOSA                0              0                   0
# 17      0     0    CERN                0              0                   0
# 18      0     0    AMST                0              0                   0
# 19      0     0  GATECH                0              0                   0
# 20      0     0    NCSA                0              0                   2
# 21      0     0    KANS                0              0                   0
# 22      0     0    SALT                0              0                   0
# 23      0     0    HAWI                0              0                   0
# 24      0     0     SRI                0              0                   0
# 25      0     0    ATLA                0              0                   0
# 26      0     0    CLEM                0              0                   2
# 27      0     0     GPN                0              0                   4
# 28      0     0    DALL                0              0                   2
# 29      0     0    INDI                0              0                   0
# 30      0     0     EDC                0              0                   0
# 31      0     0   EDUKY                0              0                   0
#
#     RTX6000 Available
# 0                   0
# 1                   0
# 2                   6
# 3                   0
# 4                   2
# 5                   0
# 6                   4
# 7                   6
# 8                   3
# 9                   6
# 10                  0
# 11                  3
# 12                  0
# 13                  0
# 14                  3
# 15                  6
# 16                  0
# 17                  0
# 18                  0
# 19                  0
# 20                  3
# 21                  0
# 22                  2
# 23                  0
# 24                  0
# 25                  0
# 26                  3
# 27                  6
# 28                  3
# 29                  0
# 30                  0
# 31                  0

# %% [markdown]
# ## Step-2: Creating a cluster from an instance type.

# %%
# Run this cell
# Initialize the variables appropriately. 
# Number of nodes in the cluster.
num_nodes=8

# Give a cluster name
slice_name='AVAH'

# Make it True if you want to include persistence storage to a single node. KEEP IT FALSE FOR THE TIME BEING.
storage=False

# get attached to the cluster. By default adding NVMe is false.
add_NVMe = True

# Make it True if you want to include GPUs to different nodes in the cluster [depends on availability].
add_gpu=False

# By default master node will not have GPUs in it. For CPU only cluster False means lower resources then the workers.
master_gpu=False

# If only t4 gpu needs to be added.
add_t4=True

# If only rtx gpu needs to be added.
add_rtx=True

# Site name, pick one site from the above list of resources.
site='UTAH'

# Select node resource:- It follows the pattern fabric.c#N.m#N.d#N , where c:cores, m:primary memory, d:disk and #N: capacity.
# eg: fabric.c4.m8.d50 means cores:4, Memory:8Gb, disk:50Gb  
# List of node instance type is provided in - https://github.com/fabric-testbed/InformationModel/blob/master/fim/slivers/data/instance_sizes.json
#instance_worker='fabric.c24.m128.d500'
instance_worker='fabric.c24.m128.d500'

# The resources of master node. It is better to be less than the worker nodes.
instance_master='fabric.c4.m8.d500'

# Operation system, Linux distribution e.g. default_ubuntu_18, default_ubuntu_20, etc.
image='default_ubuntu_18'

# %%
import pandas as pd

try:
    json_format=fablib.list_sites(output='json',quiet=True)
except Exception as e:
    print(f"Exception: {e}")

sites_df=pd.read_json(json_format)
site_df=sites_df[sites_df['name']==site]
type_t4=site_df['tesla_t4_available'].values
type_rtx=site_df['rtx6000_available'].values
nvme_available=site_df['nvme_available'].values
print("Number of Nvidia t4 available now at",site,"is:", type_t4[0])
print("Number of Nvidia rtx6000 available now at",site,"is:", type_rtx[0])
print("Number of NVMe available now at",site,"is:", nvme_available[0])

max_type_t4 = type_t4[0]
max_type_rtx = type_rtx[0]
total_gpus = max_type_t4 + max_type_rtx
# Out:
# Number of Nvidia t4 available now at UTAH is: 4
# Number of Nvidia rtx6000 available now at UTAH is: 6
# Number of NVMe available now at UTAH is: 16
# /tmp/ipykernel_81/1190618741.py:8: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   sites_df=pd.read_json(json_format)

# %%
# The max available GPU for the chosen site is mentioned above, to change it please make changes to the variables below.
# By default initialized with the available GPUs for the site.

#custom_number_of_t4 = max_type_t4
#custom_number_of_rtx = max_type_rtx

custom_number_of_t4 = 4
custom_number_of_rtx =4

if custom_number_of_t4 < max_type_t4 or custom_number_of_rtx < max_type_rtx:
    max_type_t4 = custom_number_of_t4
    max_type_rtx = custom_number_of_rtx
    total_gpus = max_type_t4 + max_type_rtx
print(total_gpus)
gpu_names=[]

for i in range(1,total_gpus+1):
    gpu_names.append("GPU_{0}".format(i))
 
print(gpu_names)
temp_t4=max_type_t4
temp_rtx=max_type_rtx

######################################################
#####                  NVMe                      #####
######################################################

# Assumption: If the number of available NVMes' are less than the number of cluster node minus the master NVMes' will not

if nvme_available >= num_nodes-1 and add_NVMe == True:
    add_NVMe = True
print(add_NVMe)
# Out:
# 8
# ['GPU_1', 'GPU_2', 'GPU_3', 'GPU_4', 'GPU_5', 'GPU_6', 'GPU_7', 'GPU_8']
# True

# %%
# Run this cell

node_names=[]
nic_names=[]
iface_names=[]
nvme_names=[]
network_name='cluster_network'
storage_name = 'gaf-storage'


for i in range(1,num_nodes+1):
    node_names.append("Node{0}".format(i))
    nic_names.append("Nic{0}".format(i))
    iface_names.append("iface{0}".format(i))
    nvme_names.append("nvme{0}".format(i))

print(node_names)
print(nic_names)
print(iface_names)
print(nvme_names)
# Out:
# ['Node1', 'Node2', 'Node3', 'Node4', 'Node5', 'Node6', 'Node7', 'Node8']
# ['Nic1', 'Nic2', 'Nic3', 'Nic4', 'Nic5', 'Nic6', 'Nic7', 'Nic8']
# ['iface1', 'iface2', 'iface3', 'iface4', 'iface5', 'iface6', 'iface7', 'iface8']
# ['nvme1', 'nvme2', 'nvme3', 'nvme4', 'nvme5', 'nvme6', 'nvme7', 'nvme8']

# %%
# Only run when persistence storage needed to be attached. 
if storage == True:
    import traceback
    from plugins import Plugins
    try:
        Plugins.load()
    except Exception as e:
        traceback.print_exc()

# %%
# Run this cell, Visit the link below to find different instance type options. 
# Read the comments carefully given below and make changes as necessary. 

try:
    slice=fablib.new_slice(name=slice_name)
    
    for i in range(num_nodes):
        if master_gpu == False and i == 0:
            node=slice.add_node(name=node_names[i],
                                site=site, 
                                instance_type=instance_master,
                                image=image)
            iface_names[i]=node.add_component(model='NIC_Basic', name=node_names[i]).get_interfaces()[0]
        
        else:
            node=slice.add_node(name=node_names[i],
                                site=site,
                                instance_type=instance_worker,
                                image=image)
            iface_names[i]=node.add_component(model='NIC_Basic',name=node_names[i]).get_interfaces()[0]
            
            if add_gpu == True:
                if add_t4 == True and temp_t4 > 0:
                    node.add_component(model='GPU_TeslaT4', name=gpu_names[i-1])
                    temp_t4 = temp_t4 - 1
                elif add_rtx == True and temp_rtx >0 and temp_t4 <=0:
                    node.add_component(model='GPU_RTX6000',name=gpu_names[i-1])
                    temp_rtx = temp_rtx - 1
            if add_NVMe == True:
                node.add_component(model='NVME_P4510', name=nvme_names[i-1])

except Exception as e:
    print(f'Exception: {e}')

# %%
# Run this cell
try:
    net_cluster=slice.add_l2network(name=network_name, interfaces=iface_names[:])
except Exception as e:
    print(f"Exception: {e}")

# %%
# Run this cell
# If this cell get executed successfully then IP address of the nodes will be displayed which can be used to ssh into the respective nodes.
# If there is an error while creating the slice/cluster, repeat from the third code cell block.

try:
    slice.submit()
except Exception as e:
    print(f'Exception: {e}')
# Out:
# Retry: 1, Time: 46 sec
# <style type="text/css">
# #T_41765 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_41765 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_41765 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_41765_row0_col0, #T_41765_row0_col1, #T_41765_row1_col0, #T_41765_row1_col1, #T_41765_row2_col0, #T_41765_row2_col1, #T_41765_row3_col0, #T_41765_row3_col1, #T_41765_row4_col0, #T_41765_row4_col1, #T_41765_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_41765_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# </style>
# <table id="T_41765">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41765_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_41765_row0_col1" class="data row0 col1" >9ef48c1f-7167-41b4-bc4a-448b361fc5ea</td>
#     </tr>
#     <tr>
#       <td id="T_41765_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_41765_row1_col1" class="data row1 col1" >AVAH</td>
#     </tr>
#     <tr>
#       <td id="T_41765_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_41765_row2_col1" class="data row2 col1" >2023-11-30 16:24:23 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_41765_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_41765_row3_col1" class="data row3 col1" >2023-11-29 16:24:23 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_41765_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_41765_row4_col1" class="data row4 col1" >68926660-da26-475d-9c40-50ebf0a5a812</td>
#     </tr>
#     <tr>
#       <td id="T_41765_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_41765_row5_col1" class="data row5 col1" >Configuring</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6615f caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_6615f th {
#   text-align: left;
# }
# #T_6615f tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6615f tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6615f .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6615f_row0_col0, #T_6615f_row0_col1, #T_6615f_row0_col2, #T_6615f_row0_col3, #T_6615f_row0_col4, #T_6615f_row0_col5, #T_6615f_row0_col6, #T_6615f_row0_col7, #T_6615f_row0_col8, #T_6615f_row0_col9, #T_6615f_row0_col10, #T_6615f_row0_col13, #T_6615f_row0_col14, #T_6615f_row0_col15, #T_6615f_row1_col0, #T_6615f_row1_col1, #T_6615f_row1_col2, #T_6615f_row1_col3, #T_6615f_row1_col4, #T_6615f_row1_col5, #T_6615f_row1_col6, #T_6615f_row1_col7, #T_6615f_row1_col8, #T_6615f_row1_col9, #T_6615f_row1_col10, #T_6615f_row1_col13, #T_6615f_row1_col14, #T_6615f_row1_col15, #T_6615f_row2_col0, #T_6615f_row2_col1, #T_6615f_row2_col2, #T_6615f_row2_col3, #T_6615f_row2_col4, #T_6615f_row2_col5, #T_6615f_row2_col6, #T_6615f_row2_col7, #T_6615f_row2_col8, #T_6615f_row2_col9, #T_6615f_row2_col10, #T_6615f_row2_col13, #T_6615f_row2_col14, #T_6615f_row2_col15, #T_6615f_row3_col0, #T_6615f_row3_col1, #T_6615f_row3_col2, #T_6615f_row3_col3, #T_6615f_row3_col4, #T_6615f_row3_col5, #T_6615f_row3_col6, #T_6615f_row3_col7, #T_6615f_row3_col8, #T_6615f_row3_col9, #T_6615f_row3_col10, #T_6615f_row3_col13, #T_6615f_row3_col14, #T_6615f_row3_col15, #T_6615f_row4_col0, #T_6615f_row4_col1, #T_6615f_row4_col2, #T_6615f_row4_col3, #T_6615f_row4_col4, #T_6615f_row4_col5, #T_6615f_row4_col6, #T_6615f_row4_col7, #T_6615f_row4_col8, #T_6615f_row4_col9, #T_6615f_row4_col10, #T_6615f_row4_col13, #T_6615f_row4_col14, #T_6615f_row4_col15, #T_6615f_row5_col0, #T_6615f_row5_col1, #T_6615f_row5_col2, #T_6615f_row5_col3, #T_6615f_row5_col4, #T_6615f_row5_col5, #T_6615f_row5_col6, #T_6615f_row5_col7, #T_6615f_row5_col8, #T_6615f_row5_col9, #T_6615f_row5_col10, #T_6615f_row5_col13, #T_6615f_row5_col14, #T_6615f_row5_col15, #T_6615f_row6_col0, #T_6615f_row6_col1, #T_6615f_row6_col2, #T_6615f_row6_col3, #T_6615f_row6_col4, #T_6615f_row6_col5, #T_6615f_row6_col6, #T_6615f_row6_col7, #T_6615f_row6_col8, #T_6615f_row6_col9, #T_6615f_row6_col10, #T_6615f_row6_col13, #T_6615f_row6_col14, #T_6615f_row6_col15, #T_6615f_row7_col0, #T_6615f_row7_col1, #T_6615f_row7_col2, #T_6615f_row7_col3, #T_6615f_row7_col4, #T_6615f_row7_col5, #T_6615f_row7_col6, #T_6615f_row7_col7, #T_6615f_row7_col8, #T_6615f_row7_col9, #T_6615f_row7_col10, #T_6615f_row7_col13, #T_6615f_row7_col14, #T_6615f_row7_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_6615f_row0_col11, #T_6615f_row1_col11, #T_6615f_row2_col11, #T_6615f_row3_col11, #T_6615f_row4_col11, #T_6615f_row5_col11, #T_6615f_row6_col11, #T_6615f_row7_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# #T_6615f_row0_col12, #T_6615f_row1_col12, #T_6615f_row2_col12, #T_6615f_row3_col12, #T_6615f_row4_col12, #T_6615f_row5_col12, #T_6615f_row6_col12, #T_6615f_row7_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_6615f">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_6615f_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_6615f_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_6615f_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_6615f_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_6615f_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_6615f_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_6615f_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_6615f_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_6615f_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_6615f_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_6615f_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_6615f_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_6615f_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_6615f_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_6615f_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_6615f_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6615f_row0_col0" class="data row0 col0" >a227c119-e6d6-4e7b-a2f6-7329629d6d95</td>
#       <td id="T_6615f_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_6615f_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_6615f_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_6615f_row0_col4" class="data row0 col4" >500</td>
#       <td id="T_6615f_row0_col5" class="data row0 col5" >default_ubuntu_18</td>
#       <td id="T_6615f_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_6615f_row0_col7" class="data row0 col7" >utah-w4.fabric-testbed.net</td>
#       <td id="T_6615f_row0_col8" class="data row0 col8" >UTAH</td>
#       <td id="T_6615f_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_6615f_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_6615f_row0_col11" class="data row0 col11" >Ticketed</td>
#       <td id="T_6615f_row0_col12" class="data row0 col12" ></td>
#       <td id="T_6615f_row0_col13" class="data row0 col13" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#       <td id="T_6615f_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/sliver.pub</td>
#       <td id="T_6615f_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/sliver</td>
#     </tr>
#     <tr>
#       <td id="T_6615f_row1_col0" class="data row1 col0" >69d99c04-5ef2-4e0c-8632-8e074ace25db</td>
#       <td id="T_6615f_row1_col1" class="data row1 col1" >Node2</td>
#       <td id="T_6615f_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_6615f_row1_col3" class="data row1 col3" >128</td>
#       <td id="T_6615f_row1_col4" class="data row1 col4" >500</td>
#       <td id="T_6615f_row1_col5" class="data row1 col5" >default_ubuntu_18</td>
#       <td id="T_6615f_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_6615f_row1_col7" class="data row1 col7" >utah-w5.fabric-testbed.net</td>
#       <td id="T_6615f_row1_col8" class="data row1 col8" >UTAH</td>
#       <td id="T_6615f_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_6615f_row1_col10" class="data row1 col10" >None</td>
#       <td id="T_6615f_row1_col11" class="data row1 col11" >Ticketed</td>
#       <td id="T_6615f_row1_col12" class="data row1 col12" ></td>
#       <td id="T_6615f_row1_col13" class="data row1 col13" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#       <td id="T_6615f_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/sliver.pub</td>
#       <td id="T_6615f_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/sliver</td>
#     </tr>
#     <tr>
#       <td id="T_6615f_row2_col0" class="data row2 col0" >8ce2feab-f027-421e-b7bb-33d62034334e</td>
#       <td id="T_6615f_row2_col1" class="data row2 col1" >Node3</td>
#       <td id="T_6615f_row2_col2" class="data row2 col2" >24</td>
#       <td id="T_6615f_row2_col3" class="data row2 col3" >128</td>
#       <td id="T_6615f_row2_col4" class="data row2 col4" >500</td>
#       <td id="T_6615f_row2_col5" class="data row2 col5" >default_ubuntu_18</td>
#       <td id="T_6615f_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T
# <style type="text/css">
# #T_a15dc caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_a15dc th {
#   text-align: left;
# }
# #T_a15dc tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a15dc tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_a15dc .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a15dc_row0_col0, #T_a15dc_row0_col1, #T_a15dc_row0_col2, #T_a15dc_row0_col3, #T_a15dc_row0_col4, #T_a15dc_row0_col5, #T_a15dc_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_a15dc_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# #T_a15dc_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_a15dc">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_a15dc_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_a15dc_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a15dc_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_a15dc_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_a15dc_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_a15dc_level0_col5" class="col_heading level0 col5" >Gateway</th>
#       <th id="T_a15dc_level0_col6" class="col_heading level0 col6" >Subnet</th>
#       <th id="T_a15dc_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_a15dc_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a15dc_row0_col0" class="data row0 col0" >4d71d803-7b68-4c78-b688-339eaa880449</td>
#       <td id="T_a15dc_row0_col1" class="data row0 col1" >cluster_network</td>
#       <td id="T_a15dc_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_a15dc_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_a15dc_row0_col4" class="data row0 col4" >UTAH</td>
#       <td id="T_a15dc_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_a15dc_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_a15dc_row0_col7" class="data row0 col7" >Ticketed</td>
#       <td id="T_a15dc_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step-3: Configuring the network and setting up the cluster

# %%
try:
    slice=fablib.get_slice(name="AVAH") # Put the cluster name that you want to delete
    #slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %%
#Run this cell

from ipaddress import IPv4Address, IPv4Network

try:
    subnet=IPv4Network("192.168.1.0/24")
    available_ips=list(subnet)[1:]
except Exception as e:
    print(f"Exception: {e}")

# %%
#try:
#    for node in slice.get_nodes():
#        node_iface=node.get_interface(network_name=network_name)
#        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
#except Exception as e:
#    print(f"Exception: {e}")

# %%
#Run this cell
#%%capture
try:
    for node in slice.get_nodes():
        node_iface=node.get_interface(network_name=network_name)
        node_IP_addr=available_ips.pop(0)
        node_iface.ip_addr_add(addr=node_IP_addr, subnet=subnet)
        
        stdout, stderr = node.execute(f'ip addr show {node_iface.get_os_interface()}')
        _, _ = node.execute('sudo apt-get update')
        stdout, stderr = node.execute('sudo apt install net-tools')        
        stdout, stderr = node.execute(f'sudo ifconfig {node_iface.get_os_interface()} up')
        
        
except Exception as e:
    print(f"Exception: {e}")
# Out:
# 3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 8e:ee:c4:45:b7:98 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.1/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::8cee:c4ff:fe45:b798/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists...
#  E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
#  3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:5c:96:36:fb:07 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.2/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::5c:96ff:fe36:fb07/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists...
#  E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
#  3: enp8s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 26:bd:b4:2a:a6:bb brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.3/24 scope global enp8s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::24bd:b4ff:fe2a:a6bb/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists...
#  E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
#  3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:d5:42:4e:0c:39 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.4/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::d5:42ff:fe4e:c39/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists...
#  E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
#  3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:8d:b7:13:2e:64 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.5/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::8d:b7ff:fe13:2e64/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists...
#  E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
#  3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:67:7f:d4:71:c5 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.6/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::67:7fff:fed4:71c5/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists...
#  E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
#  3: enp7s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:d3:ff:39:61:4c brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.7/24 scope global enp7s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::d3:ffff:fe39:614c/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists... E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
#  3: enp8s0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 0a:35:18:f2:67:26 brd ff:ff:ff:ff:ff:ff
#     inet 192.168.1.8/24 scope global enp8s0
#        valid_lft forever preferred_lft forever
#     inet6 fe80::835:18ff:fef2:6726/64 scope link
#        valid_lft forever preferred_lft forever
# Reading package lists... E: List directory /var/lib/apt/lists/partial is missing. - Acquire (2: No such file or directory)
# E: flAbsPath on /var/lib/dpkg/status failed - realpath (2: No such file or directory)
# E: Could not open file  - open (2: No such file or directory)
# E: Problem opening
# E: The package lists or status file could not be parsed or opened.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (2: No such file or directory)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
#Run this cell
# If the ping is successful, that means the nodes are connected properly if there is any error then may need to recreate the cluster or further have to look into it. 

try:
    node1=slice.get_node(name='Node1')
    
    stdout,stderr=node1.execute(f' ping -c 3 192.168.1.4')
    print(stdout)
    print(stderr)
    
except Exception as e:
    print(f'Exception: {e}')
# Out:
# PING 192.168.1.4 (192.168.1.4) 56(84) bytes of data.
# 64 bytes from 192.168.1.4: icmp_seq=1 ttl=64 time=0.140 ms
# 64 bytes from 192.168.1.4: icmp_seq=2 ttl=64 time=0.108 ms
# 64 bytes from 192.168.1.4: icmp_seq=3 ttl=64 time=0.129 ms
#
# --- 192.168.1.4 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2030ms
# rtt min/avg/max/mdev = 0.108/0.125/0.140/0.018 ms
# PING 192.168.1.4 (192.168.1.4) 56(84) bytes of data.
# 64 bytes from 192.168.1.4: icmp_seq=1 ttl=64 time=0.140 ms
# 64 bytes from 192.168.1.4: icmp_seq=2 ttl=64 time=0.108 ms
# 64 bytes from 192.168.1.4: icmp_seq=3 ttl=64 time=0.129 ms
#
# --- 192.168.1.4 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2030ms
# rtt min/avg/max/mdev = 0.108/0.125/0.140/0.018 ms

# %%
# Run this cell
# Function to create a file that contains IPs and hostnames related to it.

def append_line(file_path,text):
    with open(file_path,"a+") as file_des:
        file_des.seek(0)
        data=file_des.read(-1)
        if len(data)>0:
            file_des.write("\n")
        file_des.write(text)

# %%
# Run this cell

import os

if os.path.isfile('/home/fabric/work/hosts') or os.path.isfile('/home/fabric/work/ips.txt') or os.path.isfile('/home/fabric/work/workers'):
    os.system("rm /home/fabric/work/hosts")
    os.system("rm /home/fabric/work/ips.txt")
    os.system("rm /home/fabric/work/workers")    
else:
    print("does not exist")

if os.path.isfile('/home/fabric/work/gpu_ips.txt'):
    os.system("rm /home/fabric/work/gpu_ips.txt")
    
#os.system("rm /home/fabric/work/ips.txt")

# %%
# Run this cell

# Capturing the IP addresses, this step needs to be integrated with the IP assigning stage, coded above. Or it may stay independent.
import os

i=1
local_host="127.0.0.1 localhost"
path_to_host_file="/home/fabric/work/hosts"
path_to_ip_file="/home/fabric/work/ips.txt"
path_to_worker_ip="/home/fabric/work/workers"
path_to_gpu_ips="/home/fabric/work/gpu_ips.txt"
gpu_name="NVIDIA"

append_line(path_to_host_file,local_host)

try:
    for node in slice.get_nodes():
        stdout, stderr=node.execute("hostname -I")
        IP=stdout.split(" ")[1]
        node_name="node{0}".format(i)
        vm_names="vm{0}".format(i-1)
        append_line(path_to_ip_file,IP)
        
        stdout, stderr=node.execute("hostname")
        line=IP+" "+node_name+" "+vm_names+" "+stdout
        append_line(path_to_host_file,line)
      
    
        if(i>1):
            append_line(path_to_worker_ip,vm_names)
            #append_line(path_to_worker_ip,IP)
        
        print(line)
        print(stderr)
        
        stdout_gpu, _=node.execute('lspci | grep NVIDIA')   
        if gpu_name in stdout_gpu:
            stdout_ip, _=node.execute('hostname -I')
            ip=stdout_ip.split(" ")[1]
            append_line(path_to_gpu_ips,ip)
            #print(ip)
        
        i=i+1
except Exception as e:
    print(f"Exception: {e}")
    
print(IP)
# Out:
# 10.30.6.122 192.168.1.1 2001:400:a100:3030:f816:3eff:fe75:8623
# 5b3d02da-b518-495a-bfe5-5ff140a10a0b-node1
# 192.168.1.1 node1 vm0 5b3d02da-b518-495a-bfe5-5ff140a10a0b-node1
#
#
# 10.30.6.25 192.168.1.2 2001:400:a100:3030:f816:3eff:fe4f:ee24
# e90deda7-78df-4ccf-85be-fb09c8032038-node2
# 192.168.1.2 node2 vm1 e90deda7-78df-4ccf-85be-fb09c8032038-node2
#
#
# 10.30.6.154 192.168.1.3 2001:400:a100:3030:f816:3eff:fe7d:32c1
# e62975a1-296b-4f33-98f2-6d64a0888c52-node3
# 192.168.1.3 node3 vm2 e62975a1-296b-4f33-98f2-6d64a0888c52-node3
#
#
# 10.30.6.38 192.168.1.4 2001:400:a100:3030:f816:3eff:fea2:4e18
# 8823cf72-08c9-4891-882d-f304b8237f98-node4
# 192.168.1.4 node4 vm3 8823cf72-08c9-4891-882d-f304b8237f98-node4
#
#
# 10.30.6.109 192.168.1.5 2001:400:a100:3030:f816:3eff:fe9e:7aa4
# fc5a06f6-5534-4d1f-809d-951b2c36d178-node5
# 192.168.1.5 node5 vm4 fc5a06f6-5534-4d1f-809d-951b2c36d178-node5
#
#
# 10.30.6.45 192.168.1.6 2001:400:a100:3030:f816:3eff:fe4b:cf3d
# dd426998-3a14-4a5e-a8ae-45517f35ae37-node6
# 192.168.1.6 node6 vm5 dd426998-3a14-4a5e-a8ae-45517f35ae37-node6
#
#
# 10.30.6.77 192.168.1.7 2001:400:a100:3030:f816:3eff:fe46:4c00
# 747baa5a-f0ce-45e0-81d5-7449ab17c0c6-node7
# 192.168.1.7 node7 vm6 747baa5a-f0ce-45e0-81d5-7449ab17c0c6-node7
#
#
# 10.30.6.84 192.168.1.8 2001:400:a100:3030:f816:3eff:fe3b:6bd3
# 39235ada-8064-4653-b4fc-664afe1bf0fd-node8
# 192.168.1.8 node8 vm7 39235ada-8064-4653-b4fc-664afe1bf0fd-node8
#
#
# 192.168.1.8

# %%
# Run this cell

try:
    for node in slice.get_nodes():
        stdout, stderr=node.execute(f'sudo cp /etc/hosts /etc/hosts_backup') # if you run the command twice the back up will be overwritten, a conditional block should be written
        output_host_copy=node.upload_file(path_to_host_file,"/home/ubuntu/hosts")
        output_ip_copy=node.upload_file(path_to_ip_file,"/home/ubuntu/ips.txt")
        output_worker_copy=node.upload_file(path_to_worker_ip,"/home/ubuntu/workers")
        stdout_host_copy,stderr_host_copy=node.execute(f'sudo cp /home/ubuntu/hosts /etc/hosts')
        if os.path.isfile('/home/fabric/work/gpu_ips.txt'):
            output_gpu_copy=node.upload_file(path_to_gpu_ips,"/home/ubuntu/gpu_ips.txt")
        
        print(stderr)
        print(stderr_host_copy)
except Exception as e:
    print(f"Exception : {e}")

# %%
# Run this cell

import os

output=os.system('ssh-keygen -q -t rsa -N "" -f /home/fabric/work/id_rsa > /dev/null 2>&1')

# %%
# Run this cell

try:
    for node in slice.get_nodes():
        output_private=node.upload_file("/home/fabric/work/id_rsa","/home/ubuntu/.ssh/id_rsa")
        output_public=node.upload_file("/home/fabric/work/id_rsa.pub","/home/ubuntu/.ssh/id_rsa.pub")
        
        stdout, stderr=node.execute(f' cat /home/ubuntu/.ssh/id_rsa.pub >> /home/ubuntu/.ssh/authorized_keys')
        stdout, stderr=node.execute(f' chmod 600 /home/ubuntu/.ssh/id_rsa*')
        
        print(output_private)
        print(output_public)
        print(stderr)
        #print(stdout)
        
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -rw-------   1 1000     1000         2655 21 Nov 22:16 ?
# -rw-------   1 1000     1000          609 21 Nov 22:16 ?
#
# -rw-------   1 1000     1000         2655 21 Nov 22:16 ?
# -rw-------   1 1000     1000          609 21 Nov 22:16 ?
#
# -rw-------   1 1000     1000         2655 21 Nov 22:16 ?
# -rw-------   1 1000     1000          609 21 Nov 22:16 ?
#
# -rw-------   1 1000     1000         2655 21 Nov 22:16 ?
# -rw-------   1 1000     1000          609 21 Nov 22:16 ?
#
# -rw-------   1 1000     1000         2655 21 Nov 22:16 ?
# -rw-------   1 1000     1000          609 21 Nov 22:16 ?
#
# -rw-------   1 1000     1000         2655 21 Nov 22:16 ?
# -rw-------   1 1000     1000          609 21 Nov 22:16 ?
#
# -rw-------   1 1000     1000         2655 21 Nov 22:16 ?
# -rw-------   1 1000     1000          609 21 Nov 22:16 ?
#
# -rw-------   1 1000     1000         2655 21 Nov 22:17 ?
# -rw-------   1 1000     1000          609 21 Nov 22:17 ?

# %%
# Run this cell. This is the last cell to run. Please read the comments in the next few cells to know how to extend the lease time and how to delete a slice/cluster. 

from ipaddress import ip_address, IPv6Address
try:
    for node in slice.get_nodes():
        if type(ip_address(node.get_management_ip())) is IPv6Address:
            node.upload_file("/home/fabric/work/nat64.sh", "/home/ubuntu/nat64.sh")
            #stdout, stderr=node.execute(f' chmod +x /home/ubuntu/nat64.sh && sudo bash /home/ubuntu/nat64.sh')
            stdout, stderr=node.execute(f' chmod +x /home/ubuntu/nat64.sh && sudo bash /home/ubuntu/nat64.sh > /dev/null 2>&1')
            
            print(stdout)
            print(stderr)
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step-4: Deleting and extending lease of a slice

# %%
# Run this cell ONLY when you want to delete the cell
# To delete a slice/cluster.
try:
    slice=fablib.get_slice(name="AVAH") # Put the cluster name that you want to delete
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %%
# Run this cell ONLY when you want to exted the time of the slice. Or to extend the lease time of the slice/cluster.

import datetime
slice_name='test2' # Give the cluster/slice name that you want to extend

#Set end host to now plus 1 day
new_end_date = (datetime.datetime.utcnow() + datetime.timedelta(days=7)).strftime("%Y-%m-%d %H:%M:%S %z")
#new_end_date = (datetime.now(timezone.utc) + timedelta(days=6)).strftime("%Y-%m-%d %H:%M:%S %z")
print(type(new_end_date), new_end_date)
try:
    slice=fablib.get_slice(name=slice_name)
    slice.renew('2023-05-31 18:04:26 +0000') # Give the new lease end date and time of the slice. One can increase it by 7 days from the day of creation of the slice/cluster. 
    
    #print(f"Lease End (UTC)        : {slice.get_lease_end()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <class 'str'> 2023-06-01 02:02:16

# %%
# Run this cell ONLY to observe the new lease time.

slice_name='cluster_exp' # Give the slice/cluster name that you just extended. 
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------  ------------------------------------
# Slice Name   cluster_exp
# Slice ID     6f79613e-46f0-4323-8f04-395221080b2e
# Slice State  StableOK
# Lease End    2023-05-06 18:04:26 +0000
# -----------  ------------------------------------

# %%
# Run this cell ONLY to observe the new lease time.

slice_name='cluster_gpu' # Give the slice/cluster name that you just extended. 
try:
    slice = fablib.get_slice(name=slice_name)
    gpu_name="NVIDIA"
    for node in slice.get_nodes():
        #stdout, stderr=node.execute(f'sudo cp /etc/hosts /etc/hosts_backup') # if you run the command twice the back up will be overwritten, a conditional block should be written
        stdout_gpu, _=node.execute('lspci | grep NVIDIA')   
        if gpu_name in stdout_gpu:
            stdout_ip, _=node.execute('hostname -I')
            ip=stdout_ip.split(" ")[1]
            print(ip)
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Do not bother about the code below !!! ;-)

# %%
# Do not Run this cell

storage_name = 'gaf-storage1'

node1=slice.get_node(name='Node1')
node1.add_component(model='NVME_P4510',name='gaf-storage')
# Out:
# ---------------------------------------------------------------------------
# TopologyException                         Traceback (most recent call last)
# /tmp/ipykernel_55/829870909.py in <module>
#       2
#       3 node1=slice.get_node(name='Node1')
# ----> 4 node1.add_component(model='NVME_P4510',name='gaf-storage')
#
# /opt/conda/lib/python3.9/site-packages/fabrictestbed_extensions/fablib/node.py in add_component(self, model, name)
#     517         :rtype: Component
#     518         """
# --> 519         return Component.new_component(node=self, model=model, name=name)
#     520
#     521     def get_components(self) -> List[Component]:
#
# /opt/conda/lib/python3.9/site-packages/fabrictestbed_extensions/fablib/component.py in new_component(node, model, name)
#     120         name = Component.calculate_name(node=node, name=name)
#     121
# --> 122         return Component(node=node, fim_component=node.fim_node.add_component(
#     123             model_type=Component.component_model_map[model], name=name))
#     124
#
# /opt/conda/lib/python3.9/site-packages/fim/user/node.py in add_component(self, name, node_id, ctype, model, model_type, network_service_node_id, interface_node_ids, interface_labels, **kwargs)
#     277         # make sure name is unique within the node
#     278         if name in self.__list_components().keys():
# --> 279             raise TopologyException('Component names must be unique within node.')
#     280         # add component node and populate properties
#     281         c = Component(name=name, node_id=node_id, topo=self.topo, etype=ElementType.NEW,
#
# TopologyException: Component names must be unique within node.

# %%
slice_name='cluster_gpu_2'

try:
    slice=fablib.get_slice(name=slice_name)
except Exception as e:
    print(f"Exception: {e}")

# %%
# Do not run this cell, only for experimentation.

try:
    node = slice.get_node(name='Node4')
    print(f"{node}")
    storage = node.get_storage(name='gaf-storage')
    print(f"{storage}")
    print(f"Storage Device Name: {storage.get_device_name()}")
    #print("Mounting the storage volume")
    #stdout, stderr = node.execute(f"sudo mkdir -p /mnt/{storage_name};"
                                 # f"sudo mount {storage.get_device_name()} /mnt/{storage_name}")
    print(stdout)
    print(stderr)
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# ID                 342cfbfa-8e20-4e69-992a-64364d08db35
# Name               Node4
# Cores              4
# RAM                8
# Disk               10
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               star-w2.fabric-testbed.net
# Site               STAR
# Management IP      2001:400:a100:3030:f816:3eff:fe08:a7d4
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -J mjdbz4_0000018266@bastion-1.fabric-testbed.net ubuntu@2001:400:a100:3030:f816:3eff:fe08:a7d4
# -----------------  ------------------------------------------------------------------------------------------------------------------------------------------------
# -----------  --------------------
# Name         gaf-storage
# Details      Site-local NAS share
# Disk (G)     0
# Units        1
# PCI Address
# Model
# Type         Storage
# -----------  --------------------
# Storage Device Name: /dev/vdb
#
# mount: /mnt/gaf-storage: wrong fs type, bad option, bad superblock on /dev/vdb, missing codepage or helper program, or other error.

# %%
hosts=[]
import random
randomList=[]

while True:
    r=random.randint(1,9)
    
    if r not in randomList:
        randomList.append(r)
    if len(randomList) == 8:
        break
        
for i in range(1,num_nodes+1):
    hosts.append("{0}-w{1}.fabric-testbed.net".format(site.lower(),randomList[i-1]))
    
print(hosts)

# %%
try:
    node = slice.get_node('Node3') 
    #node.show()

    nvme1 = node.get_component(nvme_names[1])
    nvme1.show()
    nvme1.configure_nvme()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_6d212 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6d212 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6d212 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_6d212_row0_col0, #T_6d212_row0_col1, #T_6d212_row1_col0, #T_6d212_row1_col1, #T_6d212_row2_col0, #T_6d212_row2_col1, #T_6d212_row3_col0, #T_6d212_row3_col1, #T_6d212_row4_col0, #T_6d212_row4_col1, #T_6d212_row5_col0, #T_6d212_row5_col1, #T_6d212_row6_col0, #T_6d212_row6_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_6d212">
#   <caption>Component</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d212_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_6d212_row0_col1" class="data row0 col1" >Node3-nvme2</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row1_col0" class="data row1 col0" >Details</td>
#       <td id="T_6d212_row1_col1" class="data row1 col1" >Dell Express Flash NVMe P4510 1TB SFF</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row2_col0" class="data row2 col0" >Disk</td>
#       <td id="T_6d212_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row3_col0" class="data row3 col0" >Units</td>
#       <td id="T_6d212_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row4_col0" class="data row4 col0" >PCI Address</td>
#       <td id="T_6d212_row4_col1" class="data row4 col1" >['0000:00:08.0']</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row5_col0" class="data row5 col0" >Model</td>
#       <td id="T_6d212_row5_col1" class="data row5 col1" >NVME_P4510</td>
#     </tr>
#     <tr>
#       <td id="T_6d212_row6_col0" class="data row6 col0" >Type</td>
#       <td id="T_6d212_row6_col1" class="data row6 col1" >NVME</td>
#     </tr>
#   </tbody>
# </table>
# Disk /dev/nvme0n1: 894.3 GiB, 960197124096 bytes, 1875385008 sectors
# Units: sectors of 1 * 512 = 512 bytes
# Sector size (logical/physical): 512 bytes / 512 bytes
# I/O size (minimum/optimal): 512 bytes / 512 bytes
#  fdisk: cannot open /dev/nvme0: Illegal seek
#  config_nvme Fail: Node3-nvme2
# Exception: []

# %%
nvme_names[1]
# Out:
# 'nvme2'
